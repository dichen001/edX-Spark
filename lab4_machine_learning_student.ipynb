# %% [markdown]
# version 1.0.2
# #![Spark Logo](http://spark-mooc.github.io/web-assets/images/ta_Spark-logo-small.png) + ![Python Logo](http://spark-mooc.github.io/web-assets/images/python-logo-master-v3-TM-flattened_small.png)
# # **Introduction to Machine Learning with Apache Spark**
# ## **Predicting Movie Ratings**
# #### One of the most common uses of big data is to predict what users want.  This allows Google to show you relevant ads, Amazon to recommend relevant products, and Netflix to recommend movies that you might like.  This lab will demonstrate how we can use Apache Spark to recommend movies to a user.  We will start with some basic techniques, and then use the [Spark MLlib][mllib] library's Alternating Least Squares method to make more sophisticated predictions.
# #### For this lab, we will use a subset dataset of 500,000 ratings we have included for you into your VM (and on Databricks) from the [movielens 10M stable benchmark rating dataset](http://grouplens.org/datasets/movielens/). However, the same code you write will work for the full dataset, or their latest dataset of 21 million ratings.
# #### In this lab:
# #### *Part 0*: Preliminaries
# #### *Part 1*: Basic Recommendations
# #### *Part 2*: Collaborative Filtering
# #### *Part 3*: Predictions for Yourself
# #### As mentioned during the first Learning Spark lab, think carefully before calling `collect()` on any datasets.  When you are using a small dataset, calling `collect()` and then using Python to get a sense for the data locally (in the driver program) will work fine, but this will not work when you are using a large dataset that doesn't fit in memory on one machine.  Solutions that call `collect()` and do local analysis that could have been done with Spark will likely fail in the autograder and not receive full credit.
# [mllib]: https://spark.apache.org/mllib/

# %% [markdown]
# ### Code
# #### This assignment can be completed using basic Python and pySpark Transformations and Actions.  Libraries other than math are not necessary. With the exception of the ML functions that we introduce in this assignment, you should be able to complete all parts of this homework using only the Spark functions you have used in prior lab exercises (although you are welcome to use more features of Spark if you like!).

# %%
import sys
import os
from test_helper import Test

baseDir = os.path.join('data')
inputPath = os.path.join('cs100', 'lab4', 'small')

ratingsFilename = os.path.join(baseDir, inputPath, 'ratings.dat.gz')
moviesFilename = os.path.join(baseDir, inputPath, 'movies.dat')

# %% [markdown]
# ### **Part 0: Preliminaries**
# #### We read in each of the files and create an RDD consisting of parsed lines.
# #### Each line in the ratings dataset (`ratings.dat.gz`) is formatted as:
# ####   `UserID::MovieID::Rating::Timestamp`
# #### Each line in the movies (`movies.dat`) dataset is formatted as:
# ####   `MovieID::Title::Genres`
# #### The `Genres` field has the format
# ####   `Genres1|Genres2|Genres3|...`
# #### The format of these files is uniform and simple, so we can use Python [`split()`](https://docs.python.org/2/library/stdtypes.html#str.split) to parse their lines.
# #### Parsing the two files yields two RDDS
# * #### For each line in the ratings dataset, we create a tuple of (UserID, MovieID, Rating). We drop the timestamp because we do not need it for this exercise.
# * #### For each line in the movies dataset, we create a tuple of (MovieID, Title). We drop the Genres because we do not need them for this exercise.

# %%
numPartitions = 2
rawRatings = sc.textFile(ratingsFilename).repartition(numPartitions)
rawMovies = sc.textFile(moviesFilename)

def get_ratings_tuple(entry):
    """ Parse a line in the ratings dataset
    Args:
        entry (str): a line in the ratings dataset in the form of UserID::MovieID::Rating::Timestamp
    Returns:
        tuple: (UserID, MovieID, Rating)
    """
    items = entry.split('::')
    return int(items[0]), int(items[1]), float(items[2])


def get_movie_tuple(entry):
    """ Parse a line in the movies dataset
    Args:
        entry (str): a line in the movies dataset in the form of MovieID::Title::Genres
    Returns:
        tuple: (MovieID, Title)
    """
    items = entry.split('::')
    return int(items[0]), items[1]


ratingsRDD = rawRatings.map(get_ratings_tuple).cache()
moviesRDD = rawMovies.map(get_movie_tuple).cache()

ratingsCount = ratingsRDD.count()
moviesCount = moviesRDD.count()

print 'There are %s ratings and %s movies in the datasets' % (ratingsCount, moviesCount)
print 'Ratings: %s' % ratingsRDD.take(3)
print 'Movies: %s' % moviesRDD.take(3)

assert ratingsCount == 487650
assert moviesCount == 3883
assert moviesRDD.filter(lambda (id, title): title == 'Toy Story (1995)').count() == 1
assert (ratingsRDD.takeOrdered(1, key=lambda (user, movie, rating): movie)
        == [(1, 1, 5.0)])
# Out:
# There are 487650 ratings and 3883 movies in the datasets
# Ratings: [(1, 1193, 5.0), (1, 914, 3.0), (1, 2355, 5.0)]
# Movies: [(1, u'Toy Story (1995)'), (2, u'Jumanji (1995)'), (3, u'Grumpier Old Men (1995)')]

# %% [markdown]
# #### In this lab we will be examining subsets of the tuples we create (e.g., the top rated movies by users). Whenever we examine only a subset of a large dataset, there is the potential that the result will depend on the order we perform operations, such as joins, or how the data is partitioned across the workers. What we want to guarantee is that we always see the same results for a subset, independent of how we manipulate or store the data.
# #### We can do that by sorting before we examine a subset. You might think that the most obvious choice when dealing with an RDD of tuples would be to use the [`sortByKey()` method][sortbykey]. However this choice is problematic, as we can still end up with different results if the key is not unique.
# #### Note: It is important to use the [`unicode` type](https://docs.python.org/2/howto/unicode.html#the-unicode-type) instead of the `string` type as the titles are in unicode characters.
# #### Consider the following example, and note that while the sets are equal, the printed lists are usually in different order by value, *although they may randomly match up from time to time.*
# #### You can try running this multiple times.  If the last assertion fails, don't worry about it: that was just the luck of the draw.  And note that in some environments the results may be more deterministic.
# [sortbykey]: https://spark.apache.org/docs/latest/api/python/pyspark.html#pyspark.RDD.sortByKey

# %%
tmp1 = [(1, u'alpha'), (2, u'alpha'), (2, u'beta'), (3, u'alpha'), (1, u'epsilon'), (1, u'delta')]
tmp2 = [(1, u'delta'), (2, u'alpha'), (2, u'beta'), (3, u'alpha'), (1, u'epsilon'), (1, u'alpha')]

oneRDD = sc.parallelize(tmp1)
twoRDD = sc.parallelize(tmp2)
oneSorted = oneRDD.sortByKey(True).collect()
twoSorted = twoRDD.sortByKey(True).collect()
print oneSorted
print twoSorted
assert set(oneSorted) == set(twoSorted)     # Note that both lists have the same elements
assert twoSorted[0][0] < twoSorted.pop()[0] # Check that it is sorted by the keys
assert oneSorted[0:2] != twoSorted[0:2]     # Note that the subset consisting of the first two elements does not match
# Out:
# Ratings: [(1, 1193, 5.0), (1, 914, 3.0)]
# Movies: [(1, u'Toy Story (1995)'), (2, u'Jumanji (1995)')]
# [(1, u'alpha'), (1, u'epsilon'), (1, u'delta'), (2, u'alpha'), (2, u'beta'), (3, u'alpha')]
# [(1, u'delta'), (1, u'epsilon'), (1, u'alpha'), (2, u'alpha'), (2, u'beta'), (3, u'alpha')]

# %% [markdown]
# #### Even though the two lists contain identical tuples, the difference in ordering *sometimes* yields a different ordering for the sorted RDD (try running the cell repeatedly and see if the results change or the assertion fails). If we only examined the first two elements of the RDD (e.g., using `take(2)`), then we would observe different answers - **that is a really bad outcome as we want identical input data to always yield identical output**. A better technique is to sort the RDD by *both the key and value*, which we can do by combining the key and value into a single string and then sorting on that string. Since the key is an integer and the value is a unicode string, we can use a function to combine them into a single unicode string (e.g., `unicode('%.3f' % key) + ' ' + value`) before sorting the RDD using [sortBy()][sortby].
# [sortby]: https://spark.apache.org/docs/latest/api/python/pyspark.html#pyspark.RDD.sortBy

# %%
def sortFunction(tuple):
    """ Construct the sort string (does not perform actual sorting)
    Args:
        tuple: (rating, MovieName)
    Returns:
        sortString: the value to sort with, 'rating MovieName'
    """
    key = unicode('%.3f' % tuple[0])
    value = tuple[1]
    return (key + ' ' + value)


print oneRDD.sortBy(sortFunction, True).collect()
print twoRDD.sortBy(sortFunction, True).collect()
# Out:
# [(1, u'alpha'), (1, u'delta'), (1, u'epsilon'), (2, u'alpha'), (2, u'beta'), (3, u'alpha')]
# [(1, u'alpha'), (1, u'delta'), (1, u'epsilon'), (2, u'alpha'), (2, u'beta'), (3, u'alpha')]

# %% [markdown]
# #### If we just want to look at the first few elements of the RDD in sorted order, we can use the [takeOrdered][takeordered] method with the `sortFunction` we defined.
# [takeordered]: https://spark.apache.org/docs/latest/api/python/pyspark.html#pyspark.RDD.takeOrdered

# %%
oneSorted1 = oneRDD.takeOrdered(oneRDD.count(),key=sortFunction)
twoSorted1 = twoRDD.takeOrdered(twoRDD.count(),key=sortFunction)
print 'one is %s' % oneSorted1
print 'two is %s' % twoSorted1
assert oneSorted1 == twoSorted1
# Out:
# one is [(1, u'alpha'), (1, u'delta'), (1, u'epsilon'), (2, u'alpha'), (2, u'beta'), (3, u'alpha')]
# two is [(1, u'alpha'), (1, u'delta'), (1, u'epsilon'), (2, u'alpha'), (2, u'beta'), (3, u'alpha')]

# %% [markdown]
# ### **Part 1: Basic Recommendations**
# #### One way to recommend movies is to always recommend the movies with the highest average rating. In this part, we will use Spark to find the name, number of ratings, and the average rating of the 20 movies with the highest average rating and more than 500 reviews. We want to filter our movies with high ratings but fewer than or equal to 500 reviews because movies with few reviews may not have broad appeal to everyone.

# %% [markdown]
# #### **(1a) Number of Ratings and Average Ratings for a Movie**
# #### Using only Python, implement a helper function `getCountsAndAverages()` that takes a single tuple of (MovieID, (Rating1, Rating2, Rating3, ...)) and returns a tuple of (MovieID, (number of ratings, averageRating)). For example, given the tuple `(100, (10.0, 20.0, 30.0))`, your function should return `(100, (3, 20.0))`

# %%
# TODO: Replace <FILL IN> with appropriate code

# First, implement a helper function `getCountsAndAverages` using only Python
def getCountsAndAverages(IDandRatingsTuple):
    """ Calculate average rating
    Args:
        IDandRatingsTuple: a single tuple of (MovieID, (Rating1, Rating2, Rating3, ...))
    Returns:
        tuple: a tuple of (MovieID, (number of ratings, averageRating))
    """
    count = len(IDandRatingsTuple[1])
    ave = float(sum(IDandRatingsTuple[1]))/count
    return (IDandRatingsTuple[0],(count, ave))

# %%
# TEST Number of Ratings and Average Ratings for a Movie (1a)

Test.assertEquals(getCountsAndAverages((1, (1, 2, 3, 4))), (1, (4, 2.5)),
                            'incorrect getCountsAndAverages() with integer list')
Test.assertEquals(getCountsAndAverages((100, (10.0, 20.0, 30.0))), (100, (3, 20.0)),
                            'incorrect getCountsAndAverages() with float list')
Test.assertEquals(getCountsAndAverages((110, xrange(20))), (110, (20, 9.5)),
                            'incorrect getCountsAndAverages() with xrange')
# Out:
# 1 test passed.
# 1 test passed.
# 1 test passed.

# %% [markdown]
# #### **(1b) Movies with Highest Average Ratings**
# #### Now that we have a way to calculate the average ratings, we will use the `getCountsAndAverages()` helper function with Spark to determine movies with highest average ratings.
# #### The steps you should perform are:
# * #### Recall that the `ratingsRDD` contains tuples of the form (UserID, MovieID, Rating). From `ratingsRDD` create an RDD with tuples of the form (MovieID, Python iterable of Ratings for that MovieID). This transformation will yield an RDD of the form: `[(1, <pyspark.resultiterable.ResultIterable object at 0x7f16d50e7c90>), (2, <pyspark.resultiterable.ResultIterable object at 0x7f16d50e79d0>), (3, <pyspark.resultiterable.ResultIterable object at 0x7f16d50e7610>)]`. Note that you will only need to perform two Spark transformations to do this step.
# * #### Using `movieIDsWithRatingsRDD` and your `getCountsAndAverages()` helper function, compute the number of ratings and average rating for each movie to yield tuples of the form (MovieID, (number of ratings, average rating)). This transformation will yield an RDD of the form: `[(1, (993, 4.145015105740181)), (2, (332, 3.174698795180723)), (3, (299, 3.0468227424749164))]`. You can do this step with one Spark transformation
# * #### We want to see movie names, instead of movie IDs. To `moviesRDD`, apply RDD transformations that use `movieIDsWithAvgRatingsRDD` to get the movie names for `movieIDsWithAvgRatingsRDD`, yielding tuples of the form (average rating, movie name, number of ratings). This set of transformations will yield an RDD of the form: `[(1.0, u'Autopsy (Macchie Solari) (1975)', 1), (1.0, u'Better Living (1998)', 1), (1.0, u'Big Squeeze, The (1996)', 3)]`. You will need to do two Spark transformations to complete this step: first use the `moviesRDD` with `movieIDsWithAvgRatingsRDD` to create a new RDD with Movie names matched to Movie IDs, then convert that RDD into the form of (average rating, movie name, number of ratings). These transformations will yield an RDD that looks like: `[(3.6818181818181817, u'Happiest Millionaire, The (1967)', 22), (3.0468227424749164, u'Grumpier Old Men (1995)', 299), (2.882978723404255, u'Hocus Pocus (1993)', 94)]`

# %%
# TODO: Replace <FILL IN> with appropriate code

# From ratingsRDD with tuples of (UserID, MovieID, Rating) create an RDD with tuples of
# the (MovieID, iterable of Ratings for that MovieID)
movieIDsWithRatingsRDD = (ratingsRDD
                          .map(lambda (UserID, MovieID, Rating): (MovieID, Rating))
                          .groupByKey())
print 'movieIDsWithRatingsRDD: %s\n' % movieIDsWithRatingsRDD.take(3)

# Using `movieIDsWithRatingsRDD`, compute the number of ratings and average rating for each movie to
# yield tuples of the form (MovieID, (number of ratings, average rating))
movieIDsWithAvgRatingsRDD = movieIDsWithRatingsRDD.map(getCountsAndAverages)
print 'movieIDsWithAvgRatingsRDD: %s\n' % movieIDsWithAvgRatingsRDD.take(3)

# To `movieIDsWithAvgRatingsRDD`, apply RDD transformations that use `moviesRDD` to get the movie
# names for `movieIDsWithAvgRatingsRDD`, yielding tuples of the form
# (average rating, movie name, number of ratings)
movieNameWithAvgRatingsRDD = (moviesRDD
                              .join(movieIDsWithAvgRatingsRDD)
                              .map(lambda (ID,(name,(count,ave))): (ave, name, count) )
                              )
print 'movieNameWithAvgRatingsRDD: %s\n' % movieNameWithAvgRatingsRDD.take(3)
# Out:
# movieIDsWithRatingsRDD: [(2, <pyspark.resultiterable.ResultIterable object at 0xb0e3c5cc>), (4, <pyspark.resultiterable.ResultIterable object at 0xb0e3ccac>), (6, <pyspark.resultiterable.ResultIterable object at 0xb0e3c7cc>)]
#
# movieIDsWithAvgRatingsRDD: [(2, (332, 3.174698795180723)), (4, (71, 2.676056338028169)), (6, (442, 3.7918552036199094))]
#
# movieNameWithAvgRatingsRDD: [(3.6818181818181817, u'Happiest Millionaire, The (1967)', 22), (3.0468227424749164, u'Grumpier Old Men (1995)', 299), (2.882978723404255, u'Hocus Pocus (1993)', 94)]

# %%
# TEST Movies with Highest Average Ratings (1b)

Test.assertEquals(movieIDsWithRatingsRDD.count(), 3615,
                'incorrect movieIDsWithRatingsRDD.count() (expected 3615)')
movieIDsWithRatingsTakeOrdered = movieIDsWithRatingsRDD.takeOrdered(3)
Test.assertTrue(movieIDsWithRatingsTakeOrdered[0][0] == 1 and
                len(list(movieIDsWithRatingsTakeOrdered[0][1])) == 993,
                'incorrect count of ratings for movieIDsWithRatingsTakeOrdered[0] (expected 993)')
Test.assertTrue(movieIDsWithRatingsTakeOrdered[1][0] == 2 and
                len(list(movieIDsWithRatingsTakeOrdered[1][1])) == 332,
                'incorrect count of ratings for movieIDsWithRatingsTakeOrdered[1] (expected 332)')
Test.assertTrue(movieIDsWithRatingsTakeOrdered[2][0] == 3 and
                len(list(movieIDsWithRatingsTakeOrdered[2][1])) == 299,
                'incorrect count of ratings for movieIDsWithRatingsTakeOrdered[2] (expected 299)')

Test.assertEquals(movieIDsWithAvgRatingsRDD.count(), 3615,
                'incorrect movieIDsWithAvgRatingsRDD.count() (expected 3615)')
Test.assertEquals(movieIDsWithAvgRatingsRDD.takeOrdered(3),
                [(1, (993, 4.145015105740181)), (2, (332, 3.174698795180723)),
                 (3, (299, 3.0468227424749164))],
                'incorrect movieIDsWithAvgRatingsRDD.takeOrdered(3)')

Test.assertEquals(movieNameWithAvgRatingsRDD.count(), 3615,
                'incorrect movieNameWithAvgRatingsRDD.count() (expected 3615)')
Test.assertEquals(movieNameWithAvgRatingsRDD.takeOrdered(3),
                [(1.0, u'Autopsy (Macchie Solari) (1975)', 1), (1.0, u'Better Living (1998)', 1),
                 (1.0, u'Big Squeeze, The (1996)', 3)],
                 'incorrect movieNameWithAvgRatingsRDD.takeOrdered(3)')
# Out:
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.

# %% [markdown]
# #### **(1c) Movies with Highest Average Ratings and more than 500 reviews**
# #### Now that we have an RDD of the movies with highest averge ratings, we can use Spark to determine the 20 movies with highest average ratings and more than 500 reviews.
# #### Apply a single RDD transformation to `movieNameWithAvgRatingsRDD` to limit the results to movies with ratings from more than 500 people. We then use the `sortFunction()` helper function to sort by the average rating to get the movies in order of their rating (highest rating first). You will end up with an RDD of the form: `[(4.5349264705882355, u'Shawshank Redemption, The (1994)', 1088), (4.515798462852263, u"Schindler's List (1993)", 1171), (4.512893982808023, u'Godfather, The (1972)', 1047)]`

# %%
# TODO: Replace <FILL IN> with appropriate code

# Apply an RDD transformation to `movieNameWithAvgRatingsRDD` to limit the results to movies with
# ratings from more than 500 people. We then use the `sortFunction()` helper function to sort by the
# average rating to get the movies in order of their rating (highest rating first)
movieLimitedAndSortedByRatingRDD = (movieNameWithAvgRatingsRDD
                                    .filter(lambda (ave, name, count): count>500)
                                    .sortBy(sortFunction, False))
print 'Movies with highest ratings: %s' % movieLimitedAndSortedByRatingRDD.take(20)
# Out:
# Movies with highest ratings: [(4.5349264705882355, u'Shawshank Redemption, The (1994)', 1088), (4.515798462852263, u"Schindler's List (1993)", 1171), (4.512893982808023, u'Godfather, The (1972)', 1047), (4.510460251046025, u'Raiders of the Lost Ark (1981)', 1195), (4.505415162454874, u'Usual Suspects, The (1995)', 831), (4.457256461232604, u'Rear Window (1954)', 503), (4.45468509984639, u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', 651), (4.43953006219765, u'Star Wars: Episode IV - A New Hope (1977)', 1447), (4.4, u'Sixth Sense, The (1999)', 1110), (4.394285714285714, u'North by Northwest (1959)', 700), (4.379506641366224, u'Citizen Kane (1941)', 527), (4.375, u'Casablanca (1942)', 776), (4.363975155279503, u'Godfather: Part II, The (1974)', 805), (4.358816276202219, u"One Flew Over the Cuckoo's Nest (1975)", 811), (4.358173076923077, u'Silence of the Lambs, The (1991)', 1248), (4.335826477187734, u'Saving Private Ryan (1998)', 1337), (4.326241134751773, u'Chinatown (1974)', 564), (4.325383304940375, u'Life Is Beautiful (La Vita \ufffd bella) (1997)', 587), (4.324110671936759, u'Monty Python and the Holy Grail (1974)', 759), (4.3096, u'Matrix, The (1999)', 1250)]

# %%
# TEST Movies with Highest Average Ratings and more than 500 Reviews (1c)

Test.assertEquals(movieLimitedAndSortedByRatingRDD.count(), 194,
                'incorrect movieLimitedAndSortedByRatingRDD.count()')
Test.assertEquals(movieLimitedAndSortedByRatingRDD.take(20),
              [(4.5349264705882355, u'Shawshank Redemption, The (1994)', 1088),
               (4.515798462852263, u"Schindler's List (1993)", 1171),
               (4.512893982808023, u'Godfather, The (1972)', 1047),
               (4.510460251046025, u'Raiders of the Lost Ark (1981)', 1195),
               (4.505415162454874, u'Usual Suspects, The (1995)', 831),
               (4.457256461232604, u'Rear Window (1954)', 503),
               (4.45468509984639, u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', 651),
               (4.43953006219765, u'Star Wars: Episode IV - A New Hope (1977)', 1447),
               (4.4, u'Sixth Sense, The (1999)', 1110), (4.394285714285714, u'North by Northwest (1959)', 700),
               (4.379506641366224, u'Citizen Kane (1941)', 527), (4.375, u'Casablanca (1942)', 776),
               (4.363975155279503, u'Godfather: Part II, The (1974)', 805),
               (4.358816276202219, u"One Flew Over the Cuckoo's Nest (1975)", 811),
               (4.358173076923077, u'Silence of the Lambs, The (1991)', 1248),
               (4.335826477187734, u'Saving Private Ryan (1998)', 1337),
               (4.326241134751773, u'Chinatown (1974)', 564),
               (4.325383304940375, u'Life Is Beautiful (La Vita \ufffd bella) (1997)', 587),
               (4.324110671936759, u'Monty Python and the Holy Grail (1974)', 759),
               (4.3096, u'Matrix, The (1999)', 1250)], 'incorrect sortedByRatingRDD.take(20)')
# Out:
# 1 test passed.
# 1 test passed.

# %% [markdown]
# #### Using a threshold on the number of reviews is one way to improve the recommendations, but there are many other good ways to improve quality. For example, you could weight ratings by the number of ratings.

# %% [markdown]
# ## **Part 2: Collaborative Filtering**
# #### In this course, you have learned about many of the basic transformations and actions that Spark allows us to apply to distributed datasets.  Spark also exposes some higher level functionality; in particular, Machine Learning using a component of Spark called [MLlib][mllib].  In this part, you will learn how to use MLlib to make personalized movie recommendations using the movie data we have been analyzing.
# #### We are going to use a technique called [collaborative filtering][collab]. Collaborative filtering is a method of making automatic predictions (filtering) about the interests of a user by collecting preferences or taste information from many users (collaborating). The underlying assumption of the collaborative filtering approach is that if a person A has the same opinion as a person B on an issue, A is more likely to have B's opinion on a different issue x than to have the opinion on x of a person chosen randomly. You can read more about collaborative filtering [here][collab2].
# #### The image below (from [Wikipedia][collab]) shows an example of predicting of the user's rating using collaborative filtering. At first, people rate different items (like videos, images, games). After that, the system is making predictions about a user's rating for an item, which the user has not rated yet. These predictions are built upon the existing ratings of other users, who have similar ratings with the active user. For instance, in the image below the system has made a prediction, that the active user will not like the video.
# ![collaborative filtering](https://courses.edx.org/c4x/BerkeleyX/CS100.1x/asset/Collaborative_filtering.gif)
# [mllib]: https://spark.apache.org/mllib/
# [collab]: https://en.wikipedia.org/?title=Collaborative_filtering
# [collab2]: http://recommender-systems.org/collaborative-filtering/

# %% [markdown]
# #### For movie recommendations, we start with a matrix whose entries are movie ratings by users (shown in red in the diagram below).  Each column represents a user (shown in green) and each row represents a particular movie (shown in blue).
# #### Since not all users have rated all movies, we do not know all of the entries in this matrix, which is precisely why we need collaborative filtering.  For each user, we have ratings for only a subset of the movies.  With collaborative filtering, the idea is to approximate the ratings matrix by factorizing it as the product of two matrices: one that describes properties of each user (shown in green), and one that describes properties of each movie (shown in blue).
# ![factorization](http://spark-mooc.github.io/web-assets/images/matrix_factorization.png)
# #### We want to select these two matrices such that the error for the users/movie pairs where we know the correct ratings is minimized.  The [Alternating Least Squares][als] algorithm does this by first randomly filling the users matrix with values and then optimizing the value of the movies such that the error is minimized.  Then, it holds the movies matrix constrant and optimizes the value of the user's matrix.  This alternation between which matrix to optimize is the reason for the "alternating" in the name.
# #### This optimization is what's being shown on the right in the image above.  Given a fixed set of user factors (i.e., values in the users matrix), we use the known ratings to find the best values for the movie factors using the optimization written at the bottom of the figure.  Then we "alternate" and pick the best user factors given fixed movie factors.
# #### For a simple example of what the users and movies matrices might look like, check out the [videos from Lecture 8][videos] or the [slides from Lecture 8][slides]
# [videos]: https://courses.edx.org/courses/BerkeleyX/CS100.1x/1T2015/courseware/00eb8b17939b4889a41a6d8d2f35db83/3bd3bba368be4102b40780550d3d8da6/
# [slides]: https://courses.edx.org/c4x/BerkeleyX/CS100.1x/asset/Week4Lec8.pdf
# [als]: https://en.wikiversity.org/wiki/Least-Squares_Method

# %% [markdown]
# #### **(2a) Creating a Training Set**
# #### Before we jump into using machine learning, we need to break up the `ratingsRDD` dataset into three pieces:
# * #### A training set (RDD), which we will use to train models
# * #### A validation set (RDD), which we will use to choose the best model
# * #### A test set (RDD), which we will use for our experiments
# #### To randomly split the dataset into the multiple groups, we can use the pySpark [randomSplit()](https://spark.apache.org/docs/latest/api/python/pyspark.html#pyspark.RDD.randomSplit) transformation. `randomSplit()` takes a set of splits and and seed and returns multiple RDDs.

# %%
trainingRDD, validationRDD, testRDD = ratingsRDD.randomSplit([6, 2, 2], seed=0L)

print 'Training: %s, validation: %s, test: %s\n' % (trainingRDD.count(),
                                                    validationRDD.count(),
                                                    testRDD.count())
print trainingRDD.take(3)
print validationRDD.take(3)
print testRDD.take(3)

assert trainingRDD.count() == 292716
assert validationRDD.count() == 96902
assert testRDD.count() == 98032

assert trainingRDD.filter(lambda t: t == (1, 914, 3.0)).count() == 1
assert trainingRDD.filter(lambda t: t == (1, 2355, 5.0)).count() == 1
assert trainingRDD.filter(lambda t: t == (1, 595, 5.0)).count() == 1

assert validationRDD.filter(lambda t: t == (1, 1287, 5.0)).count() == 1
assert validationRDD.filter(lambda t: t == (1, 594, 4.0)).count() == 1
assert validationRDD.filter(lambda t: t == (1, 1270, 5.0)).count() == 1

assert testRDD.filter(lambda t: t == (1, 1193, 5.0)).count() == 1
assert testRDD.filter(lambda t: t == (1, 2398, 4.0)).count() == 1
assert testRDD.filter(lambda t: t == (1, 1035, 5.0)).count() == 1
# Out:
# Training: 292716, validation: 96902, test: 98032
#
# [(1, 914, 3.0), (1, 2355, 5.0), (1, 595, 5.0)]
# [(1, 1287, 5.0), (1, 594, 4.0), (1, 1270, 5.0)]
# [(1, 1193, 5.0), (1, 2398, 4.0), (1, 1035, 5.0)]

# %% [markdown]
# #### After splitting the dataset, your training set has about 293,000 entries and the validation and test sets each have about 97,000 entries (the exact number of entries in each dataset varies slightly due to the random nature of the `randomSplit()` transformation.

# %% [markdown]
# #### **(2b) Root Mean Square Error (RMSE)**
# #### In the next part, you will generate a few different models, and will need a way to decide which model is best. We will use the [Root Mean Square Error](https://en.wikipedia.org/wiki/Root-mean-square_deviation) (RMSE) or Root Mean Square Deviation (RMSD) to compute the error of each model.  RMSE is a frequently used measure of the differences between values (sample and population values) predicted by a model or an estimator and the values actually observed. The RMSD represents the sample standard deviation of the differences between predicted values and observed values. These individual differences are called residuals when the calculations are performed over the data sample that was used for estimation, and are called prediction errors when computed out-of-sample. The RMSE serves to aggregate the magnitudes of the errors in predictions for various times into a single measure of predictive power. RMSE is a good measure of accuracy, but only to compare forecasting errors of different models for a particular variable and not between variables, as it is scale-dependent.
# ####  The RMSE is the square root of the average value of the square of `(actual rating - predicted rating)` for all users and movies for which we have the actual rating. Versions of Spark MLlib beginning with Spark 1.4 include a [RegressionMetrics](https://spark.apache.org/docs/latest/api/python/pyspark.mllib.html#pyspark.mllib.evaluation.RegressionMetrics) modiule that can be used to compute the RMSE. However, since we are using Spark 1.3.1, we will write our own function.
# #### Write a function to compute the sum of squared error given `predictedRDD` and `actualRDD` RDDs. Both RDDs consist of tuples of the form (UserID, MovieID, Rating)
# #### Given two ratings RDDs, *x* and *y* of size *n*, we define RSME as follows: $ RMSE = \sqrt{\frac{\sum_{i = 1}^{n} (x_i - y_i)^2}{n}}$
# #### To calculate RSME, the steps you should perform are:
# * #### Transform `predictedRDD` into the tuples of the form ((UserID, MovieID), Rating). For example, tuples like `[((1, 1), 5), ((1, 2), 3), ((1, 3), 4), ((2, 1), 3), ((2, 2), 2), ((2, 3), 4)]`. You can perform this step with a single Spark transformation.
# * #### Transform `actualRDD` into the tuples of the form ((UserID, MovieID), Rating). For example, tuples like `[((1, 2), 3), ((1, 3), 5), ((2, 1), 5), ((2, 2), 1)]`. You can perform this step with a single Spark transformation.
# * #### Using only RDD transformations (you only need to perform two transformations), compute the squared error for each *matching* entry (i.e., the same (UserID, MovieID) in each RDD) in the reformatted RDDs - do *not* use `collect()` to perform this step. Note that not every (UserID, MovieID) pair will appear in both RDDs - if a pair does not appear in both RDDs, then it does not contribute to the RMSE. You will end up with an RDD with entries of the form $ (x_i - y_i)^2$ You might want to check out Python's [math](https://docs.python.org/2/library/math.html) module to see how to compute these values
# * #### Using an RDD action (but **not** `collect()`), compute the total squared error: $ SE = \sum_{i = 1}^{n} (x_i - y_i)^2 $
# * #### Compute *n* by using an RDD action (but **not** `collect()`), to count the number of pairs for which you computed the total squared error
# * #### Using the total squared error and the number of pairs, compute the RSME. Make sure you compute this value as a [float](https://docs.python.org/2/library/stdtypes.html#numeric-types-int-float-long-complex).
# #### Note: Your solution must only use transformations and actions on RDDs. Do _not_ call `collect()` on either RDD.

# %%
# TODO: Replace <FILL IN> with appropriate code
import math

def computeError(predictedRDD, actualRDD):
    """ Compute the root mean squared error between predicted and actual
    Args:
        predictedRDD: predicted ratings for each movie and each user where each entry is in the form
                      (UserID, MovieID, Rating)
        actualRDD: actual ratings where each entry is in the form (UserID, MovieID, Rating)
    Returns:
        RSME (float): computed RSME value
    """
    # Transform predictedRDD into the tuples of the form ((UserID, MovieID), Rating)
    predictedReformattedRDD = predictedRDD.map(lambda (uid,mid,rating): ((uid,mid),rating))

    # Transform actualRDD into the tuples of the form ((UserID, MovieID), Rating)
    actualReformattedRDD = actualRDD.map(lambda (uid,mid,rating): ((uid,mid),rating))

    # Compute the squared error for each matching entry (i.e., the same (User ID, Movie ID) in each
    # RDD) in the reformatted RDDs using RDD transformtions - do not use collect()
    squaredErrorsRDD = (predictedReformattedRDD
                        .join(actualReformattedRDD)
                        .map(lambda ((uid,mid),(r1,r2)): ((r1-r2)**2))
                        )

    # Compute the total squared error - do not use collect()
    totalError = squaredErrorsRDD.reduce(lambda x,y: x+y)

    # Count the number of entries for which you computed the total squared error
    numRatings = squaredErrorsRDD.count()

    # Using the total squared error and the number of entries, compute the RSME
    return math.sqrt(float(totalError)/numRatings)


# sc.parallelize turns a Python list into a Spark RDD.
testPredicted = sc.parallelize([
    (1, 1, 5),
    (1, 2, 3),
    (1, 3, 4),
    (2, 1, 3),
    (2, 2, 2),
    (2, 3, 4)])
testActual = sc.parallelize([
     (1, 2, 3),
     (1, 3, 5),
     (2, 1, 5),
     (2, 2, 1)])
testPredicted2 = sc.parallelize([
     (2, 2, 5),
     (1, 2, 5)])
testError = computeError(testPredicted, testActual)
print 'Error for test dataset (should be 1.22474487139): %s' % testError

testError2 = computeError(testPredicted2, testActual)
print 'Error for test dataset2 (should be 3.16227766017): %s' % testError2

testError3 = computeError(testActual, testActual)
print 'Error for testActual dataset (should be 0.0): %s' % testError3
# Out:
# Error for test dataset (should be 1.22474487139): 1.22474487139
# Error for test dataset2 (should be 3.16227766017): 3.16227766017
# Error for testActual dataset (should be 0.0): 0.0

# %%
# TEST Root Mean Square Error (2b)
Test.assertTrue(abs(testError - 1.22474487139) < 0.00000001,
                'incorrect testError (expected 1.22474487139)')
Test.assertTrue(abs(testError2 - 3.16227766017) < 0.00000001,
                'incorrect testError2 result (expected 3.16227766017)')
Test.assertTrue(abs(testError3 - 0.0) < 0.00000001,
                'incorrect testActual result (expected 0.0)')
# Out:
# 1 test passed.
# 1 test passed.
# 1 test passed.

# %% [markdown]
# #### **(2c) Using ALS.train()**
# #### In this part, we will use the MLlib implementation of Alternating Least Squares, [ALS.train()](https://spark.apache.org/docs/latest/api/python/pyspark.mllib.html#pyspark.mllib.recommendation.ALS). ALS takes a training dataset (RDD) and several parameters that control the model creation process. To determine the best values for the parameters, we will use ALS to train several models, and then we will select the best model and use the parameters from that model in the rest of this lab exercise.
# #### The process we will use for determining the best model is as follows:
# * #### Pick a set of model parameters. The most important parameter to `ALS.train()` is the *rank*, which is the number of rows in the Users matrix (green in the diagram above) or the number of columns in the Movies matrix (blue in the diagram above). (In general, a lower rank will mean higher error on the training dataset, but a high rank may lead to [overfitting](https://en.wikipedia.org/wiki/Overfitting).)  We will train models with ranks of 4, 8, and 12 using the `trainingRDD` dataset.
# * #### Create a model using `ALS.train(trainingRDD, rank, seed=seed, iterations=iterations, lambda_=regularizationParameter)` with three parameters: an RDD consisting of tuples of the form (UserID, MovieID, rating) used to train the model, an integer rank (4, 8, or 12), a number of iterations to execute (we will use 5 for the `iterations` parameter), and a regularization coefficient (we will use 0.1 for the `regularizationParameter`).
# * #### For the prediction step, create an input RDD, `validationForPredictRDD`, consisting of (UserID, MovieID) pairs that you extract from `validationRDD`. You will end up with an RDD of the form: `[(1, 1287), (1, 594), (1, 1270)]`
# * #### Using the model and `validationForPredictRDD`, we can predict rating values by calling [model.predictAll()](https://spark.apache.org/docs/latest/api/python/pyspark.mllib.html#pyspark.mllib.recommendation.MatrixFactorizationModel.predictAll) with the `validationForPredictRDD` dataset, where `model` is the model we generated with ALS.train().  `predictAll` accepts an RDD with each entry in the format (userID, movieID) and outputs an RDD with each entry in the format (userID, movieID, rating).
# * #### Evaluate the quality of the model by using the `computeError()` function you wrote in part (2b) to compute the error between the predicted ratings and the actual ratings in `validationRDD`.
# ####  Which rank produces the best model, based on the RMSE with the `validationRDD` dataset?
# #### Note: It is likely that this operation will take a noticeable amount of time (around a minute in our VM); you can observe its progress on the [Spark Web UI](http://localhost:4040). Probably most of the time will be spent running your `computeError()` function, since, unlike the Spark ALS implementation (and the Spark 1.4 [RegressionMetrics](https://spark.apache.org/docs/latest/api/python/pyspark.mllib.html#pyspark.mllib.evaluation.RegressionMetrics) module), this does not use a fast linear algebra library and needs to run some Python code for all 100k entries.

# %%
# TODO: Replace <FILL IN> with appropriate code
from pyspark.mllib.recommendation import ALS

validationForPredictRDD = validationRDD.map(lambda (userID, movieID, rating):(userID, movieID))

seed = 5L
iterations = 5
regularizationParameter = 0.1
ranks = [4, 8, 12]
errors = [0, 0, 0]
err = 0
tolerance = 0.03

minError = float('inf')
bestRank = -1
bestIteration = -1
for rank in ranks:
    model = ALS.train(trainingRDD, rank, seed=seed, iterations=iterations,
                      lambda_=regularizationParameter)
    predictedRatingsRDD = model.predictAll(validationForPredictRDD)
    error = computeError(predictedRatingsRDD, validationRDD)
    errors[err] = error
    err += 1
    print 'For rank %s the RMSE is %s' % (rank, error)
    if error < minError:
        minError = error
        bestRank = rank

print 'The best model was trained with rank %s' % bestRank
# Out:
# For rank 4 the RMSE is 0.892734779484
# For rank 8 the RMSE is 0.890121292255
# For rank 12 the RMSE is 0.890216118367
# The best model was trained with rank 8

# %%
# TEST Using ALS.train (2c)
Test.assertEquals(trainingRDD.getNumPartitions(), 2,
                  'incorrect number of partitions for trainingRDD (expected 2)')
Test.assertEquals(validationForPredictRDD.count(), 96902,
                  'incorrect size for validationForPredictRDD (expected 96902)')
Test.assertEquals(validationForPredictRDD.filter(lambda t: t == (1, 1907)).count(), 1,
                  'incorrect content for validationForPredictRDD')
Test.assertTrue(abs(errors[0] - 0.883710109497) < tolerance, 'incorrect errors[0]')
Test.assertTrue(abs(errors[1] - 0.878486305621) < tolerance, 'incorrect errors[1]')
Test.assertTrue(abs(errors[2] - 0.876832795659) < tolerance, 'incorrect errors[2]')
# Out:
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.
# 1 test passed.

# %% [markdown]
# #### **(2d) Testing Your Model**
# #### So far, we used the `trainingRDD` and `validationRDD` datasets to select the best model.  Since we used these two datasets to determine what model is best, we cannot use them to test how good the model is - otherwise we would be very vulnerable to [overfitting](https://en.wikipedia.org/wiki/Overfitting).  To decide how good our model is, we need to use the `testRDD` dataset.  We will use the `bestRank` you determined in part (2c) to create a model for predicting the ratings for the test dataset and then we will compute the RMSE.
# #### The steps you should perform are:
# * #### Train a model, using the `trainingRDD`, `bestRank` from part (2c), and the parameters you used in in part (2c): `seed=seed`, `iterations=iterations`, and `lambda_=regularizationParameter` - make sure you include **all** of the parameters.
# * #### For the prediction step, create an input RDD, `testForPredictingRDD`, consisting of (UserID, MovieID) pairs that you extract from `testRDD`. You will end up with an RDD of the form: `[(1, 1287), (1, 594), (1, 1270)]`
# * #### Use [myModel.predictAll()](https://spark.apache.org/docs/latest/api/python/pyspark.mllib.html#pyspark.mllib.recommendation.MatrixFactorizationModel.predictAll) to predict rating values for the test dataset.
# * #### For validation, use the `testRDD`and your `computeError` function to compute the RMSE between `testRDD` and the `predictedTestRDD` from the model.
# * #### Evaluate the quality of the model by using the `computeError()` function you wrote in part (2b) to compute the error between the predicted ratings and the actual ratings in `testRDD`.

# %%
# TODO: Replace <FILL IN> with appropriate code
myModel = ALS.train(trainingRDD, bestRank, seed=seed, iterations=iterations,
                      lambda_=regularizationParameter)
testForPredictingRDD = testRDD.map(lambda (userID, movieID, rating):(userID, movieID))
predictedTestRDD = myModel.predictAll(testForPredictingRDD)

testRMSE = computeError(testRDD, predictedTestRDD)

print 'The model had a RMSE on the test set of %s' % testRMSE
# Out:
# The model had a RMSE on the test set of 0.891048561304

# %%
# TEST Testing Your Model (2d)
Test.assertTrue(abs(testRMSE - 0.87809838344) < tolerance, 'incorrect testRMSE')
# Out:
# 1 test passed.

# %% [markdown]
# #### **(2e) Comparing Your Model**
# #### Looking at the RMSE for the results predicted by the model versus the values in the test set is one way to evalute the quality of our model. Another way to evaluate the model is to evaluate the error from a test set where every rating is the average rating for the training set.
# #### The steps you should perform are:
# * #### Use the `trainingRDD` to compute the average rating across all movies in that training dataset.
# * #### Use the average rating that you just determined and the `testRDD` to create an RDD with entries of the form (userID, movieID, average rating).
# * #### Use your `computeError` function to compute the RMSE between the `testRDD` validation RDD that you just created and the `testForAvgRDD`.

# %%
# TODO: Replace <FILL IN> with appropriate code

trainingAvgRating = trainingRDD.map(lambda (userID, movieID, rating):rating).mean()
print 'The average rating for movies in the training set is %s' % trainingAvgRating

testForAvgRDD = testRDD.map(lambda (UserID, MovieID, Rating): (UserID, MovieID, trainingAvgRating))
testAvgRMSE = computeError(testRDD, testForAvgRDD)
print 'The RMSE on the average set is %s' % testAvgRMSE
# Out:
# The average rating for movies in the training set is 3.57409571052
# The RMSE on the average set is 1.12036693569

# %%
# TEST Comparing Your Model (2e)
Test.assertTrue(abs(trainingAvgRating - 3.57409571052) < 0.000001,
                'incorrect trainingAvgRating (expected 3.57409571052)')
Test.assertTrue(abs(testAvgRMSE - 1.12036693569) < 0.000001,
                'incorrect testAvgRMSE (expected 1.12036693569)')
# Out:
# 1 test passed.
# 1 test passed.

# %% [markdown]
# #### You now have code to predict how users will rate movies!

# %% [markdown]
# ## **Part 3: Predictions for Yourself**
# #### The ultimate goal of this lab exercise is to predict what movies to recommend to yourself.  In order to do that, you will first need to add ratings for yourself to the `ratingsRDD` dataset.

# %% [markdown]
# #### **(3a) Your Movie Ratings**
# #### To help you provide ratings for yourself, we have included the following code to list the names and movie IDs of the 50 highest-rated movies from `movieLimitedAndSortedByRatingRDD` which we created in part 1 the lab.

# %%
print 'Most rated movies:'
print '(average rating, movie name, number of reviews)'
for ratingsTuple in movieLimitedAndSortedByRatingRDD.take(50):
    print ratingsTuple
print "************************"
for i in moviesRDD.take(100000):
    print i
# Out:
# Most rated movies:
# (average rating, movie name, number of reviews)
# (4.5349264705882355, u'Shawshank Redemption, The (1994)', 1088)
# (4.515798462852263, u"Schindler's List (1993)", 1171)
# (4.512893982808023, u'Godfather, The (1972)', 1047)
# (4.510460251046025, u'Raiders of the Lost Ark (1981)', 1195)
# (4.505415162454874, u'Usual Suspects, The (1995)', 831)
# (4.457256461232604, u'Rear Window (1954)', 503)
# (4.45468509984639, u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', 651)
# (4.43953006219765, u'Star Wars: Episode IV - A New Hope (1977)', 1447)
# (4.4, u'Sixth Sense, The (1999)', 1110)
# (4.394285714285714, u'North by Northwest (1959)', 700)
# (4.379506641366224, u'Citizen Kane (1941)', 527)
# (4.375, u'Casablanca (1942)', 776)
# (4.363975155279503, u'Godfather: Part II, The (1974)', 805)
# (4.358816276202219, u"One Flew Over the Cuckoo's Nest (1975)", 811)
# (4.358173076923077, u'Silence of the Lambs, The (1991)', 1248)
# (4.335826477187734, u'Saving Private Ryan (1998)', 1337)
# (4.326241134751773, u'Chinatown (1974)', 564)
# (4.325383304940375, u'Life Is Beautiful (La Vita \ufffd bella) (1997)', 587)
# (4.324110671936759, u'Monty Python and the Holy Grail (1974)', 759)
# (4.3096, u'Matrix, The (1999)', 1250)
# (4.309457579972183, u'Star Wars: Episode V - The Empire Strikes Back (1980)', 1438)
# (4.30379746835443, u'Young Frankenstein (1974)', 553)
# (4.301346801346801, u'Psycho (1960)', 594)
# (4.296438883541867, u'Pulp Fiction (1994)', 1039)
# (4.286535303776683, u'Fargo (1996)', 1218)
# (4.282367447595561, u'GoodFellas (1990)', 811)
# (4.27943661971831, u'American Beauty (1999)', 1775)
# (4.268053855569155, u'Wizard of Oz, The (1939)', 817)
# (4.267774699907664, u'Princess Bride, The (1987)', 1083)
# (4.253333333333333, u'Graduate, The (1967)', 600)
# (4.236263736263736, u'Run Lola Run (Lola rennt) (1998)', 546)
# (4.233807266982622, u'Amadeus (1984)', 633)
# (4.232558139534884, u'Toy Story 2 (1999)', 860)
# (4.232558139534884, u'This Is Spinal Tap (1984)', 516)
# (4.228494623655914, u'Almost Famous (2000)', 744)
# (4.2250755287009065, u'Christmas Story, A (1983)', 662)
# (4.216757741347905, u'Glory (1989)', 549)
# (4.213358070500927, u'Apocalypse Now (1979)', 539)
# (4.20992028343667, u'L.A. Confidential (1997)', 1129)
# (4.204733727810651, u'Blade Runner (1982)', 845)
# (4.1886120996441285, u'Sling Blade (1996)', 562)
# (4.184615384615385, u'Braveheart (1995)', 1300)
# (4.184168012924071, u'Butch Cassidy and the Sundance Kid (1969)', 619)
# (4.182509505703422, u'Good Will Hunting (1997)', 789)
# (4.166969147005445, u'Taxi Driver (1976)', 551)
# (4.162767039674466, u'Terminator, The (1984)', 983)
# (4.157545605306799, u'Reservoir Dogs (1992)', 603)
# (4.153333333333333, u'Jaws (1975)', 750)
# (4.149840595111583, u'Alien (1979)', 941)
# (4.145015105740181, u'Toy Story (1995)', 993)
# ************************
# (1, u'Toy Story (1995)')
# (2, u'Jumanji (1995)')
# (3, u'Grumpier Old Men (1995)')
# (4, u'Waiting to Exhale (1995)')
# (5, u'Father of the Bride Part II (1995)')
# (6, u'Heat (1995)')
# (7, u'Sabrina (1995)')
# (8, u'Tom and Huck (1995)')
# (9, u'Sudden Death (1995)')
# (10, u'GoldenEye (1995)')
# (11, u'American President, The (1995)')
# (12, u'Dracula: Dead and Loving It (1995)')
# (13, u'Balto (1995)')
# (14, u'Nixon (1995)')
# (15, u'Cutthroat Island (1995)')
# (16, u'Casino (1995)')
# (17, u'Sense and Sensibility (1995)')
# (18, u'Four Rooms (1995)')
# (19, u'Ace Ventura: When Nature Calls (1995)')
# (20, u'Money Train (1995)')
# (21, u'Get Shorty (1995)')
# (22, u'Copycat (1995)')
# (23, u'Assassins (1995)')
# (24, u'Powder (1995)')
# (25, u'Leaving Las Vegas (1995)')
# (26, u'Othello (1995)')
# (27, u'Now and Then (1995)')
# (28, u'Persuasion (1995)')
# (29, u'City of Lost Children, The (1995)')
# (30, u'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)')
# (31, u'Dangerous Minds (1995)')
# (32, u'Twelve Monkeys (1995)')
# (33, u'Wings of Courage (1995)')
# (34, u'Babe (1995)')
# (35, u'Carrington (1995)')
# (36, u'Dead Man Walking (1995)')
# (37, u'Across the Sea of Time (1995)')
# (38, u'It Takes Two (1995)')
# (39, u'Clueless (1995)')
# (40, u'Cry, the Beloved Country (1995)')
# (41, u'Richard III (1995)')
# (42, u'Dead Presidents (1995)')
# (43, u'Restoration (1995)')
# (44, u'Mortal Kombat (1995)')
# (45, u'To Die For (1995)')
# (46, u'How to Make an American Quilt (1995)')
# (47, u'Seven (Se7en) (1995)')
# (48, u'Pocahontas (1995)')
# (49, u'When Night Is Falling (1995)')
# (50, u'Usual Suspects, The (1995)')
# (51, u'Guardian Angel (1994)')
# (52, u'Mighty Aphrodite (1995)')
# (53, u'Lamerica (1994)')
# (54, u'Big Green, The (1995)')
# (55, u'Georgia (1995)')
# (56, u'Kids of the Round Table (1995)')
# (57, u'Home for the Holidays (1995)')
# (58, u'Postino, Il (The Postman) (1994)')
# (59, u'Confessional, The (Le Confessionnal) (1995)')
# (60, u'Indian in the Cupboard, The (1995)')
# (61, u'Eye for an Eye (1996)')
# (62, u"Mr. Holland's Opus (1995)")
# (63, u"Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)")
# (64, u'Two if by Sea (1996)')
# (65, u'Bio-Dome (1996)')
# (66, u'Lawnmower Man 2: Beyond Cyberspace (1996)')
# (67, u'Two Bits (1995)')
# (68, u'French Twist (Gazon maudit) (1995)')
# (69, u'Friday (1995)')
# (70, u'From Dusk Till Dawn (1996)')
# (71, u'Fair Game (1995)')
# (72, u'Kicking and Screaming (1995)')
# (73, u'Mis\ufffdrables, Les (1995)')
# (74, u'Bed of Roses (1996)')
# (75, u'Big Bully (1996)')
# (76, u'Screamers (1995)')
# (77, u'Nico Icon (1995)')
# (78, u'Crossing Guard, The (1995)')
# (79, u'Juror, The (1996)')
# (80, u'White Balloon, The (Badkonake Sefid ) (1995)')
# (81, u"Things to Do in Denver when You're Dead (1995)")
# (82, u"Antonia's Line (Antonia) (1995)")
# (83, u'Once Upon a Time... When We Were Colored (1995)')
# (84, u'Last Summer in the Hamptons (1995)')
# (85, u'Angels and Insects (1995)')
# (86, u'White Squall (1996)')
# (87, u'Dunston Checks In (1996)')
# (88, u'Black Sheep (1996)')
# (89, u'Nick of Time (1995)')
# (90, u'Journey of August King, The (1995)')
# (92, u'Mary Reilly (1996)')
# (93, u'Vampire in Brooklyn (1995)')
# (94, u'Beautiful Girls (1996)')
# (95, u'Broken Arrow (1996)')
# (96, u'In the Bleak Midwinter (1995)')
# (97, u'Hate (Haine, La) (1995)')
# (98, u'Shopping (1994)')
# (99, u'Heidi Fleiss: Hollywood Madam (1995)')
# (100, u'City Hall (1996)')
# (101, u'Bottle Rocket (1996)')
# (102, u'Mr. Wrong (1996)')
# (103, u'Unforgettable (1996)')
# (104, u'Happy Gilmore (1996)')
# (105, u'Bridges of Madison County, The (1995)')
# (106, u'Nobody Loves Me (Keiner liebt mich) (1994)')
# (107, u'Muppet Treasure Island (1996)')
# (108, u'Catwalk (1995)')
# (109, u'Headless Body in Topless Bar (1995)')
# (110, u'Braveheart (1995)')
# (111, u'Taxi Driver (1976)')
# (112, u'Rumble in the Bronx (1995)')
# (113, u'Before and After (1996)')
# (114, u"Margaret's Museum (1995)")
# (115, u'Happiness Is in the Field (1995)')
# (116, u'Anne Frank Remembered (1995)')
# (117, u"Young Poisoner's Handbook, The (1995)")
# (118, u'If Lucy Fell (1996)')
# (119, u'Steal Big, Steal Little (1995)')
# (120, u'Race the Sun (1996)')
# (121, u'Boys of St. Vincent, The (1993)')
# (122, u'Boomerang (1992)')
# (123, u'Chungking Express (1994)')
# (124, u"Star Maker, The (Uomo delle stelle, L') (1995)")
# (125, u'Flirting With Disaster (1996)')
# (126, u'NeverEnding Story III, The (1994)')
# (127, u'Silence of the Palace, The (Saimt el Qusur) (1994)')
# (128, u"Jupiter's Wife (1994)")
# (129, u'Pie in the Sky (1995)')
# (130, u'Angela (1995)')
# (131, u'Frankie Starlight (1995)')
# (132, u'Jade (1995)')
# (133, u'Nueba Yol (1995)')
# (134, u'Sonic Outlaws (1995)')
# (135, u'Down Periscope (1996)')
# (136, u'From the Journals of Jean Seberg (1995)')
# (137, u'Man of the Year (1995)')
# (138, u'Neon Bible, The (1995)')
# (139, u'Target (1995)')
# (140, u'Up Close and Personal (1996)')
# (141, u'Birdcage, The (1996)')
# (142, u'Shadows (Cienie) (1988)')
# (143, u'Gospa (1995)')
# (144, u'Brothers McMullen, The (1995)')
# (145, u'Bad Boys (1995)')
# (146, u'Amazing Panda Adventure, The (1995)')
# (147, u'Basketball Diaries, The (1995)')
# (148, u'Awfully Big Adventure, An (1995)')
# (149, u'Amateur (1994)')
# (150, u'Apollo 13 (1995)')
# (151, u'Rob Roy (1995)')
# (152, u'Addiction, The (1995)')
# (153, u'Batman Forever (1995)')
# (154, u'Belle de jour (1967)')
# (155, u'Beyond Rangoon (1995)')
# (156, u'Blue in the Face (1995)')
# (157, u'Canadian Bacon (1994)')
# (158, u'Casper (1995)')
# (159, u'Clockers (1995)')
# (160, u'Congo (1995)')
# (161, u'Crimson Tide (1995)')
# (162, u'Crumb (1994)')
# (163, u'Desperado (1995)')
# (164, u'Devil in a Blue Dress (1995)')
# (165, u'Die Hard: With a Vengeance (1995)')
# (166, u'Doom Generation, The (1995)')
# (167, u'Feast of July (1995)')
# (168, u'First Knight (1995)')
# (169, u'Free Willy 2: The Adventure Home (1995)')
# (170, u'Hackers (1995)')
# (171, u'Jeffrey (1995)')
# (172, u'Johnny Mnemonic (1995)')
# (173, u'Judge Dredd (1995)')
# (174, u'Jury Duty (1995)')
# (175, u'Kids (1995)')
# (176, u'Living in Oblivion (1995)')
# (177, u'Lord of Illusions (1995)')
# (178, u'Love & Human Remains (1993)')
# (179, u'Mad Love (1995)')
# (180, u'Mallrats (1995)')
# (181, u'Mighty Morphin Power Rangers: The Movie (1995)')
# (182, u'Moonlight and Valentino (1995)')
# (183, u'Mute Witness (1994)')
# (184, u'Nadja (1994)')
# (185, u'Net, The (1995)')
# (186, u'Nine Months (1995)')
# (187, u'Party Girl (1995)')
# (188, u'Prophecy, The (1995)')
# (189, u'Reckless (1995)')
# (190, u'Safe (1995)')
# (191, u'Scarlet Letter, The (1995)')
# (192, u'Show, The (1995)')
# (193, u'Showgirls (1995)')
# (194, u'Smoke (1995)')
# (195, u'Something to Talk About (1995)')
# (196, u'Species (1995)')
# (197, u'Stars Fell on Henrietta, The (1995)')
# (198, u'Strange Days (1995)')
# (199, u'Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)')
# (200, u'Tie That Binds, The (1995)')
# (201, u'Three Wishes (1995)')
# (202, u'Total Eclipse (1995)')
# (203, u'To Wong Foo, Thanks for Everything! Julie Newmar (1995)')
# (204, u'Under Siege 2: Dark Territory (1995)')
# (205, u'Unstrung Heroes (1995)')
# (206, u'Unzipped (1995)')
# (207, u'Walk in the Clouds, A (1995)')
# (208, u'Waterworld (1995)')
# (209, u"White Man's Burden (1995)")
# (210, u'Wild Bill (1995)')
# (211, u'Browning Version, The (1994)')
# (212, u'Bushwhacked (1995)')
# (213, u'Burnt By the Sun (Utomlyonnye solntsem) (1994)')
# (214, u'Before the Rain (Pred dozhdot) (1994)')
# (215, u'Before Sunrise (1995)')
# (216, u'Billy Madison (1995)')
# (217, u'Babysitter, The (1995)')
# (218, u'Boys on the Side (1995)')
# (219, u'Cure, The (1995)')
# (220, u'Castle Freak (1995)')
# (222, u'Circle of Friends (1995)')
# (223, u'Clerks (1994)')
# (224, u'Don Juan DeMarco (1995)')
# (225, u'Disclosure (1994)')
# (226, u'Dream Man (1995)')
# (227, u'Drop Zone (1994)')
# (228, u'Destiny Turns on the Radio (1995)')
# (229, u'Death and the Maiden (1994)')
# (230, u'Dolores Claiborne (1994)')
# (231, u'Dumb & Dumber (1994)')
# (232, u'Eat Drink Man Woman (1994)')
# (233, u'Exotica (1994)')
# (234, u'Exit to Eden (1994)')
# (235, u'Ed Wood (1994)')
# (236, u'French Kiss (1995)')
# (237, u'Forget Paris (1995)')
# (238, u'Far From Home: The Adventures of Yellow Dog (1995)')
# (239, u'Goofy Movie, A (1995)')
# (240, u'Hideaway (1995)')
# (241, u'Fluke (1995)')
# (242, u'Farinelli: il castrato (1994)')
# (243, u'Gordy (1995)')
# (244, u'Gumby: The Movie (1995)')
# (245, u'Glass Shield, The (1994)')
# (246, u'Hoop Dreams (1994)')
# (247, u'Heavenly Creatures (1994)')
# (248, u'Houseguest (1994)')
# (249, u'Immortal Beloved (1994)')
# (250, u'Heavyweights (1994)')
# (251, u'Hunted, The (1995)')
# (252, u'I.Q. (1994)')
# (253, u'Interview with the Vampire (1994)')
# (254, u'Jefferson in Paris (1995)')
# (255, u'Jerky Boys, The (1994)')
# (256, u'Junior (1994)')
# (257, u'Just Cause (1995)')
# (258, u"Kid in King Arthur's Court, A (1995)")
# (259, u'Kiss of Death (1995)')
# (260, u'Star Wars: Episode IV - A New Hope (1977)')
# (261, u'Little Women (1994)')
# (262, u'Little Princess, A (1995)')
# (263, u'Ladybird Ladybird (1994)')
# (264, u"Enfer, L' (1994)")
# (265, u'Like Water for Chocolate (Como agua para chocolate) (1992)')
# (266, u'Legends of the Fall (1994)')
# (267, u'Major Payne (1994)')
# (268, u'Little Odessa (1994)')
# (269, u'My Crazy Life (Mi vida loca) (1993)')
# (270, u'Love Affair (1994)')
# (271, u'Losing Isaiah (1995)')
# (272, u'Madness of King George, The (1994)')
# (273, u"Mary Shelley's Frankenstein (1994)")
# (274, u'Man of the House (1995)')
# (275, u'Mixed Nuts (1994)')
# (276, u'Milk Money (1994)')
# (277, u'Miracle on 34th Street (1994)')
# (278, u'Miami Rhapsody (1995)')
# (279, u'My Family (1995)')
# (280, u'Murder in the First (1995)')
# (281, u"Nobody's Fool (1994)")
# (282, u'Nell (1994)')
# (283, u'New Jersey Drive (1995)')
# (284, u'New York Cop (1996)')
# (285, u'Beyond Bedlam (1993)')
# (286, u'Nemesis 2: Nebula (1995)')
# (287, u'Nina Takes a Lover (1994)')
# (288, u'Natural Born Killers (1994)')
# (289, u'Only You (1994)')
# (290, u'Once Were Warriors (1994)')
# (291, u'Poison Ivy II (1995)')
# (292, u'Outbreak (1995)')
# (293, u'Professional, The (a.k.a. Leon: The Professional) (1994)')
# (294, u'Perez Family, The (1995)')
# (295, u"Pyromaniac's Love Story, A (1995)")
# (296, u'Pulp Fiction (1994)')
# (297, u'Panther (1995)')
# (298, u'Pushing Hands (1992)')
# (299, u'Priest (1994)')
# (300, u'Quiz Show (1994)')
# (301, u'Picture Bride (1995)')
# (302, u'Queen Margot (La Reine Margot) (1994)')
# (303, u'Quick and the Dead, The (1995)')
# (304, u'Roommates (1995)')
# (305, u'Ready to Wear (Pret-A-Porter) (1994)')
# (306, u'Three Colors: Red (1994)')
# (307, u'Three Colors: Blue (1993)')
# (308, u'Three Colors: White (1994)')
# (309, u'Red Firecracker, Green Firecracker (1994)')
# (310, u'Rent-a-Kid (1995)')
# (311, u'Relative Fear (1994)')
# (312, u'Stuart Saves His Family (1995)')
# (313, u'Swan Princess, The (1994)')
# (314, u'Secret of Roan Inish, The (1994)')
# (315, u'Specialist, The (1994)')
# (316, u'Stargate (1994)')
# (317, u'Santa Clause, The (1994)')
# (318, u'Shawshank Redemption, The (1994)')
# (319, u'Shallow Grave (1994)')
# (320, u'Suture (1993)')
# (321, u'Strawberry and Chocolate (Fresa y chocolate) (1993)')
# (322, u'Swimming with Sharks (1995)')
# (324, u'Sum of Us, The (1994)')
# (325, u"National Lampoon's Senior Trip (1995)")
# (326, u'To Live (Huozhe) (1994)')
# (327, u'Tank Girl (1995)')
# (328, u'Tales From the Crypt Presents: Demon Knight (1995)')
# (329, u'Star Trek: Generations (1994)')
# (330, u'Tales from the Hood (1995)')
# (331, u'Tom & Viv (1994)')
# (332, u'Village of the Damned (1995)')
# (333, u'Tommy Boy (1995)')
# (334, u'Vanya on 42nd Street (1994)')
# (335, u'Underneath, The (1995)')
# (336, u'Walking Dead, The (1995)')
# (337, u"What's Eating Gilbert Grape (1993)")
# (338, u'Virtuosity (1995)')
# (339, u'While You Were Sleeping (1995)')
# (340, u'War, The (1994)')
# (341, u'Double Happiness (1994)')
# (342, u"Muriel's Wedding (1994)")
# (343, u'Baby-Sitters Club, The (1995)')
# (344, u'Ace Ventura: Pet Detective (1994)')
# (345, u'Adventures of Priscilla, Queen of the Desert, The (1994)')
# (346, u'Backbeat (1993)')
# (347, u'Bitter Moon (1992)')
# (348, u'Bullets Over Broadway (1994)')
# (349, u'Clear and Present Danger (1994)')
# (350, u'Client, The (1994)')
# (351, u'Corrina, Corrina (1994)')
# (352, u'Crooklyn (1994)')
# (353, u'Crow, The (1994)')
# (354, u'Cobb (1994)')
# (355, u'Flintstones, The (1994)')
# (356, u'Forrest Gump (1994)')
# (357, u'Four Weddings and a Funeral (1994)')
# (358, u'Higher Learning (1995)')
# (359, u'I Like It Like That (1994)')
# (360, u'I Love Trouble (1994)')
# (361, u'It Could Happen to You (1994)')
# (362, u'Jungle Book, The (1994)')
# (363, u'Wonderful, Horrible Life of Leni Riefenstahl, The (Die Macht der Bilder) (1993)')
# (364, u'Lion King, The (1994)')
# (365, u'Little Buddha (1993)')
# (366, u"Wes Craven's New Nightmare (1994)")
# (367, u'Mask, The (1994)')
# (368, u'Maverick (1994)')
# (369, u'Mrs. Parker and the Vicious Circle (1994)')
# (370, u'Naked Gun 33 1/3: The Final Insult (1994)')
# (371, u'Paper, The (1994)')
# (372, u'Reality Bites (1994)')
# (373, u'Red Rock West (1992)')
# (374, u'Richie Rich (1994)')
# (375, u'Safe Passage (1994)')
# (376, u'River Wild, The (1994)')
# (377, u'Speed (1994)')
# (378, u'Speechless (1994)')
# (379, u'Timecop (1994)')
# (380, u'True Lies (1994)')
# (381, u'When a Man Loves a Woman (1994)')
# (382, u'Wolf (1994)')
# (383, u'Wyatt Earp (1994)')
# (384, u'Bad Company (1995)')
# (385, u'Man of No Importance, A (1994)')
# (386, u'S.F.W. (1994)')
# (387, u'Low Down Dirty Shame, A (1994)')
# (388, u'Boys Life (1995)')
# (389, u'Colonel Chabert, Le (1994)')
# (390, u'Faster Pussycat! Kill! Kill! (1965)')
# (391, u"Jason's Lyric (1994)")
# (392, u'Secret Adventures of Tom Thumb, The (1993)')
# (393, u'Street Fighter (1994)')
# (394, u'Coldblooded (1995)')
# (395, u'Desert Winds (1995)')
# (396, u'Fall Time (1995)')
# (397, u'Fear, The (1995)')
# (398, u'Frank and Ollie (1995)')
# (399, u'Girl in the Cadillac (1995)')
# (400, u'Homage (1995)')
# (401, u'Mirage (1995)')
# (402, u'Open Season (1996)')
# (403, u'Two Crimes (1995)')
# (404, u'Brother Minister: The Assassination of Malcolm X (1994)')
# (405, u'Highlander III: The Sorcerer (1994)')
# (406, u'Federal Hill (1994)')
# (407, u'In the Mouth of Madness (1995)')
# (408, u'8 Seconds (1994)')
# (409, u'Above the Rim (1994)')
# (410, u'Addams Family Values (1993)')
# (411, u'You So Crazy (1994)')
# (412, u'Age of Innocence, The (1993)')
# (413, u'Airheads (1994)')
# (414, u'Air Up There, The (1994)')
# (415, u'Another Stakeout (1993)')
# (416, u'Bad Girls (1994)')
# (417, u'Barcelona (1994)')
# (418, u'Being Human (1993)')
# (419, u'Beverly Hillbillies, The (1993)')
# (420, u'Beverly Hills Cop III (1994)')
# (421, u'Black Beauty (1994)')
# (422, u'Blink (1994)')
# (423, u'Blown Away (1994)')
# (424, u'Blue Chips (1994)')
# (425, u'Blue Sky (1994)')
# (426, u'Body Snatchers (1993)')
# (427, u'Boxing Helena (1993)')
# (428, u'Bronx Tale, A (1993)')
# (429, u'Cabin Boy (1994)')
# (430, u'Calendar Girl (1993)')
# (431, u"Carlito's Way (1993)")
# (432, u"City Slickers II: The Legend of Curly's Gold (1994)")
# (433, u'Clean Slate (1994)')
# (434, u'Cliffhanger (1993)')
# (435, u'Coneheads (1993)')
# (436, u'Color of Night (1994)')
# (437, u'Cops and Robbersons (1994)')
# (438, u'Cowboy Way, The (1994)')
# (439, u'Dangerous Game (1993)')
# (440, u'Dave (1993)')
# (441, u'Dazed and Confused (1993)')
# (442, u'Demolition Man (1993)')
# (443, u'Endless Summer 2, The (1994)')
# (444, u'Even Cowgirls Get the Blues (1993)')
# (445, u'Fatal Instinct (1993)')
# (446, u'Farewell My Concubine (1993)')
# (447, u'Favor, The (1994)')
# (448, u'Fearless (1993)')
# (449, u'Fear of a Black Hat (1993)')
# (450, u'With Honors (1994)')
# (451, u'Flesh and Bone (1993)')
# (452, u"Widows' Peak (1994)")
# (453, u'For Love or Money (1993)')
# (454, u'Firm, The (1993)')
# (455, u'Free Willy (1993)')
# (456, u'Fresh (1994)')
# (457, u'Fugitive, The (1993)')
# (458, u'Geronimo: An American Legend (1993)')
# (459, u'Getaway, The (1994)')
# (460, u'Getting Even with Dad (1994)')
# (461, u'Go Fish (1994)')
# (462, u'Good Man in Africa, A (1994)')
# (463, u'Guilty as Sin (1993)')
# (464, u'Hard Target (1993)')
# (465, u'Heaven & Earth (1993)')
# (466, u'Hot Shots! Part Deux (1993)')
# (467, u'Live Nude Girls (1995)')
# (468, u'Englishman Who Went Up a Hill, But Came Down a Mountain, The (1995)')
# (469, u'House of the Spirits, The (1993)')
# (470, u'House Party 3 (1994)')
# (471, u'Hudsucker Proxy, The (1994)')
# (472, u"I'll Do Anything (1994)")
# (473, u'In the Army Now (1994)')
# (474, u'In the Line of Fire (1993)')
# (475, u'In the Name of the Father (1993)')
# (476, u'Inkwell, The (1994)')
# (477, u"What's Love Got to Do with It? (1993)")
# (478, u'Jimmy Hollywood (1994)')
# (479, u'Judgment Night (1993)')
# (480, u'Jurassic Park (1993)')
# (481, u'Kalifornia (1993)')
# (482, u'Killing Zoe (1994)')
# (483, u'King of the Hill (1993)')
# (484, u'Lassie (1994)')
# (485, u'Last Action Hero (1993)')
# (486, u'Life with Mikey (1993)')
# (487, u'Lightning Jack (1994)')
# (488, u'M. Butterfly (1993)')
# (489, u'Made in America (1993)')
# (490, u'Malice (1993)')
# (491, u'Man Without a Face, The (1993)')
# (492, u'Manhattan Murder Mystery (1993)')
# (493, u'Menace II Society (1993)')
# (494, u'Executive Decision (1996)')
# (495, u'In the Realm of the Senses (Ai no corrida) (1976)')
# (496, u'What Happened Was... (1994)')
# (497, u'Much Ado About Nothing (1993)')
# (498, u'Mr. Jones (1993)')
# (499, u'Mr. Wonderful (1993)')
# (500, u'Mrs. Doubtfire (1993)')
# (501, u'Naked (1993)')
# (502, u'Next Karate Kid, The (1994)')
# (503, u'New Age, The (1994)')
# (504, u'No Escape (1994)')
# (505, u'North (1994)')
# (506, u'Orlando (1993)')
# (507, u'Perfect World, A (1993)')
# (508, u'Philadelphia (1993)')
# (509, u'Piano, The (1993)')
# (510, u'Poetic Justice (1993)')
# (511, u'Program, The (1993)')
# (512, u"Robert A. Heinlein's The Puppet Masters (1994)")
# (513, u'Radioland Murders (1994)')
# (514, u'Ref, The (1994)')
# (515, u'Remains of the Day, The (1993)')
# (516, u'Renaissance Man (1994)')
# (517, u'Rising Sun (1993)')
# (518, u'Road to Wellville, The (1994)')
# (519, u'Robocop 3 (1993)')
# (520, u'Robin Hood: Men in Tights (1993)')
# (521, u'Romeo Is Bleeding (1993)')
# (522, u'Romper Stomper (1992)')
# (523, u'Ruby in Paradise (1993)')
# (524, u'Rudy (1993)')
# (525, u'Saint of Fort Washington, The (1993)')
# (526, u'Savage Nights (Nuits fauves, Les) (1992)')
# (527, u"Schindler's List (1993)")
# (528, u'Scout, The (1994)')
# (529, u'Searching for Bobby Fischer (1993)')
# (530, u'Second Best (1994)')
# (531, u'Secret Garden, The (1993)')
# (532, u'Serial Mom (1994)')
# (533, u'Shadow, The (1994)')
# (534, u'Shadowlands (1993)')
# (535, u'Short Cuts (1993)')
# (536, u'Simple Twist of Fate, A (1994)')
# (537, u'Sirens (1994)')
# (538, u'Six Degrees of Separation (1993)')
# (539, u'Sleepless in Seattle (1993)')
# (540, u'Sliver (1993)')
# (541, u'Blade Runner (1982)')
# (542, u'Son in Law (1993)')
# (543, u'So I Married an Axe Murderer (1993)')
# (544, u'Striking Distance (1993)')
# (545, u'Harlem (1993)')
# (546, u'Super Mario Bros. (1993)')
# (547, u'Surviving the Game (1994)')
# (548, u'Terminal Velocity (1994)')
# (549, u'Thirty-Two Short Films About Glenn Gould (1993)')
# (550, u'Threesome (1994)')
# (551, u'Nightmare Before Christmas, The (1993)')
# (552, u'Three Musketeers, The (1993)')
# (553, u'Tombstone (1993)')
# (554, u'Trial by Jury (1994)')
# (555, u'True Romance (1993)')
# (556, u'War Room, The (1993)')
# (557, u'Mamma Roma (1962)')
# (558, u'Pagemaster, The (1994)')
# (559, u'Paris, France (1993)')
# (560, u'Beans of Egypt, Maine, The (1994)')
# (561, u'Killer (Bulletproof Heart) (1994)')
# (562, u'Welcome to the Dollhouse (1995)')
# (563, u'Germinal (1993)')
# (564, u'Chasers (1994)')
# (565, u'Cronos (1992)')
# (566, u'Naked in New York (1994)')
# (567, u'Kika (1993)')
# (568, u'Bhaji on the Beach (1993)')
# (569, u'Little Big League (1994)')
# (570, u'Slingshot, The (K\ufffddisbellan ) (1993)')
# (571, u'Wedding Gift, The (1994)')
# (572, u'Foreign Student (1994)')
# (573, u'Ciao, Professore! (Io speriamo che me la cavo ) (1993)')
# (574, u'Spanking the Monkey (1994)')
# (575, u'Little Rascals, The (1994)')
# (576, u'Fausto (1993)')
# (577, u'Andre (1994)')
# (578, u'Hour of the Pig, The (1993)')
# (579, u'Scorta, La (1993)')
# (580, u'Princess Caraboo (1994)')
# (581, u'Celluloid Closet, The (1995)')
# (582, u'Metisse (Caf\ufffd au Lait) (1993)')
# (583, u'Dear Diary (Caro Diario) (1994)')
# (584, u"I Don't Want to Talk About It (De eso no se habla) (1993)")
# (585, u'Brady Bunch Movie, The (1995)')
# (586, u'Home Alone (1990)')
# (587, u'Ghost (1990)')
# (588, u'Aladdin (1992)')
# (589, u'Terminator 2: Judgment Day (1991)')
# (590, u'Dances with Wolves (1990)')
# (591, u'Tough and Deadly (1995)')
# (592, u'Batman (1989)')
# (593, u'Silence of the Lambs, The (1991)')
# (594, u'Snow White and the Seven Dwarfs (1937)')
# (595, u'Beauty and the Beast (1991)')
# (596, u'Pinocchio (1940)')
# (597, u'Pretty Woman (1990)')
# (598, u'Window to Paris (1994)')
# (599, u'Wild Bunch, The (1969)')
# (600, u'Love and a .45 (1994)')
# (601, u"Wooden Man's Bride, The (Wu Kui) (1994)")
# (602, u'Great Day in Harlem, A (1994)')
# (603, u'Bye Bye, Love (1995)')
# (604, u'Criminals (1996)')
# (605, u'One Fine Day (1996)')
# (606, u'Candyman: Farewell to the Flesh (1995)')
# (607, u'Century (1993)')
# (608, u'Fargo (1996)')
# (609, u'Homeward Bound II: Lost in San Francisco (1996)')
# (610, u'Heavy Metal (1981)')
# (611, u'Hellraiser: Bloodline (1996)')
# (612, u'Pallbearer, The (1996)')
# (613, u'Jane Eyre (1996)')
# (614, u'Loaded (1994)')
# (615, u'Bread and Chocolate (Pane e cioccolata) (1973)')
# (616, u'Aristocats, The (1970)')
# (617, u'Flower of My Secret, The (La Flor de Mi Secreto) (1995)')
# (618, u'Two Much (1996)')
# (619, u'Ed (1996)')
# (620, u'Scream of Stone (Schrei aus Stein) (1991)')
# (621, u'My Favorite Season (1993)')
# (623, u'Modern Affair, A (1995)')
# (624, u'Condition Red (1995)')
# (625, u'Asfour Stah (1990)')
# (626, u'Thin Line Between Love and Hate, A (1996)')
# (627, u'Last Supper, The (1995)')
# (628, u'Primal Fear (1996)')
# (629, u'Rude (1995)')
# (630, u'Carried Away (1996)')
# (631, u'All Dogs Go to Heaven 2 (1996)')
# (632, u'Land and Freedom (Tierra y libertad) (1995)')
# (633, u'Denise Calls Up (1995)')
# (634, u'Theodore Rex (1995)')
# (635, u'Family Thing, A (1996)')
# (636, u'Frisk (1995)')
# (637, u'Sgt. Bilko (1996)')
# (638, u'Jack and Sarah (1995)')
# (639, u'Girl 6 (1996)')
# (640, u'Diabolique (1996)')
# (641, u'Little Indian, Big City (Un indien dans la ville) (1994)')
# (642, u'Roula (1995)')
# (643, u'Peanuts - Die Bank zahlt alles (1996)')
# (644, u'Happy Weekend (1996)')
# (645, u'Nelly & Monsieur Arnaud (1995)')
# (647, u'Courage Under Fire (1996)')
# (648, u'Mission: Impossible (1996)')
# (649, u'Cold Fever (\ufffd k\ufffdldum klaka) (1994)')
# (650, u'Moll Flanders (1996)')
# (651, u'Superweib, Das (1996)')
# (652, u'301, 302 (1995)')
# (653, u'Dragonheart (1996)')
# (654, u'Und keiner weint mir nach (1996)')
# (655, u'Mutters Courage (1995)')
# (656, u'Eddie (1996)')
# (657, u'Yankee Zulu (1994)')
# (658, u"Billy's Holiday (1995)")
# (659, u'Purple Noon (1960)')
# (660, u'August (1996)')
# (661, u'James and the Giant Peach (1996)')
# (662, u'Fear (1996)')
# (663, u'Kids in the Hall: Brain Candy (1996)')
# (664, u'Faithful (1996)')
# (665, u'Underground (1995)')
# (666, u'All Things Fair (1996)')
# (667, u'Bloodsport 2 (1995)')
# (668, u'Pather Panchali (1955)')
# (669, u'Aparajito (1956)')
# (670, u'World of Apu, The (Apur Sansar) (1959)')
# (671, u'Mystery Science Theater 3000: The Movie (1996)')
# (672, u'Tarantella (1995)')
# (673, u'Space Jam (1996)')
# (674, u'Barbarella (1968)')
# (675, u'Hostile Intentions (1994)')
# (676, u'They Bite (1996)')
# (678, u'Some Folks Call It a Sling Blade (1993)')
# (679, u'Run of the Country, The (1995)')
# (680, u'Alphaville (1965)')
# (681, u'Clean Slate (Coup de Torchon) (1981)')
# (682, u'Tigrero: A Film That Was Never Made (1994)')
# (683, u"Eye of Vichy, The (Oeil de Vichy, L') (1993)")
# (684, u'Windows (1980)')
# (685, u"It's My Party (1995)")
# (687, u'Country Life (1994)')
# (688, u'Operation Dumbo Drop (1995)')
# (690, u'Promise, The (Versprechen, Das) (1994)')
# (691, u'Mrs. Winterbourne (1996)')
# (692, u'Solo (1996)')
# (693, u'Under the Domin Tree (Etz Hadomim Tafus) (1994)')
# (694, u'Substitute, The (1996)')
# (695, u'True Crime (1995)')
# (696, u'Butterfly Kiss (1995)')
# (697, u'Feeling Minnesota (1996)')
# (698, u'Delta of Venus (1994)')
# (699, u'To Cross the Rubicon (1991)')
# (700, u'Angus (1995)')
# (701, u'Daens (1992)')
# (702, u'Faces (1968)')
# (703, u'Boys (1996)')
# (704, u'Quest, The (1996)')
# (705, u'Cosi (1996)')
# (706, u'Sunset Park (1996)')
# (707, u'Mulholland Falls (1996)')
# (708, u'Truth About Cats & Dogs, The (1996)')
# (709, u'Oliver & Company (1988)')
# (710, u'Celtic Pride (1996)')
# (711, u'Flipper (1996)')
# (712, u'Captives (1994)')
# (713, u'Of Love and Shadows (1994)')
# (714, u'Dead Man (1995)')
# (715, u'Horseman on the Roof, The (Hussard sur le toit, Le) (1995)')
# (716, u'Switchblade Sisters (1975)')
# (717, u'Mouth to Mouth (Boca a boca) (1995)')
# (718, u'Visitors, The (Les Visiteurs) (1993)')
# (719, u'Multiplicity (1996)')
# (720, u'Wallace & Gromit: The Best of Aardman Animation (1996)')
# (721, u'Halfmoon (Paul Bowles - Halbmond) (1995)')
# (722, u'Haunted World of Edward D. Wood Jr., The (1995)')
# (723, u'Two Friends (1986)')
# (724, u'Craft, The (1996)')
# (725, u'Great White Hype, The (1996)')
# (726, u'Last Dance (1996)')
# (727, u'War Stories (1995)')
# (728, u'Cold Comfort Farm (1995)')
# (729, u'Institute Benjamenta, or This Dream People Call Human Life (1995)')
# (730, u'Low Life, The (1994)')
# (731, u"Heaven's Prisoners (1996)")
# (732, u'Original Gangstas (1996)')
# (733, u'Rock, The (1996)')
# (734, u'Getting Away With Murder (1996)')
# (735, u'Cemetery Man (Dellamorte Dellamore) (1994)')
# (736, u'Twister (1996)')
# (737, u'Barb Wire (1996)')
# (738, u'Garcu, Le (1995)')
# (739, u'Honigmond (1996)')
# (741, u'Ghost in the Shell (Kokaku kidotai) (1995)')
# (742, u'Thinner (1996)')
# (743, u'Spy Hard (1996)')
# (744, u'Brothers in Trouble (1995)')
# (745, u'Close Shave, A (1995)')
# (746, u'Force of Evil (1948)')
# (747, u'Stupids, The (1996)')
# (748, u'Arrival, The (1996)')
# (749, u'Man from Down Under, The (1943)')
# (750, u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)')
# (751, u'Careful (1992)')
# (752, u'Vermont Is For Lovers (1992)')
# (753, u'Month by the Lake, A (1995)')
# (754, u'Gold Diggers: The Secret of Bear Mountain (1995)')
# (755, u'Kim (1950)')
# (756, u'Carmen Miranda: Bananas Is My Business (1994)')
# (757, u'Ashes of Time (1994)')
# (758, u'Jar, The (Khomreh) (1992)')
# (759, u'Maya Lin: A Strong Clear Vision (1994)')
# (760, u'Stalingrad (1993)')
# (761, u'Phantom, The (1996)')
# (762, u'Striptease (1996)')
# (763, u'Last of the High Kings, The (a.k.a. Summer Fling) (1996)')
# (764, u'Heavy (1995)')
# (765, u'Jack (1996)')
# (766, u'I Shot Andy Warhol (1996)')
# (767, u'Grass Harp, The (1995)')
# (768, u"Someone Else's America (1995)")
# (769, u'Marlene Dietrich: Shadow and Light (1996)')
# (770, u'Costa Brava (1946)')
# (771, u'Vie est belle, La (Life is Rosey) (1987)')
# (772, u'Quartier Mozart (1992)')
# (773, u'Touki Bouki (Journey of the Hyena) (1973)')
# (774, u"Wend Kuuni (God's Gift) (1982)")
# (775, u'Spirits of the Dead (Tre Passi nel Delirio) (1968)')
# (776, u'Babyfever (1994)')
# (777, u"Pharaoh's Army (1995)")
# (778, u'Trainspotting (1996)')
# (779, u"'Til There Was You (1997)")
# (780, u'Independence Day (ID4) (1996)')
# (781, u'Stealing Beauty (1996)')
# (782, u'Fan, The (1996)')
# (783, u'Hunchback of Notre Dame, The (1996)')
# (784, u'Cable Guy, The (1996)')
# (785, u'Kingpin (1996)')
# (786, u'Eraser (1996)')
# (787, u'Gate of Heavenly Peace, The (1995)')
# (788, u'Nutty Professor, The (1996)')
# (789, u'I, Worst of All (Yo, la peor de todas) (1990)')
# (790, u'An Unforgettable Summer (1994)')
# (791, u'Last Klezmer: Leopold Kozlowski, His Life and Music, The (1995)')
# (792, u'Hungarian Fairy Tale, A (1987)')
# (793, u"My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993)")
# (794, u'Midnight Dancers (Sibak) (1994)')
# (795, u'Somebody to Love (1994)')
# (796, u'Very Natural Thing, A (1974)')
# (797, u'Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)')
# (798, u'Daylight (1996)')
# (799, u'Frighteners, The (1996)')
# (800, u'Lone Star (1996)')
# (801, u'Harriet the Spy (1996)')
# (802, u'Phenomenon (1996)')
# (803, u'Walking and Talking (1996)')
# (804, u"She's the One (1996)")
# (805, u'Time to Kill, A (1996)')
# (806, u'American Buffalo (1996)')
# (807, u'Rendezvous in Paris (Rendez-vous de Paris, Les) (1995)')
# (808, u'Alaska (1996)')
# (809, u'Fled (1996)')
# (810, u'Kazaam (1996)')
# (811, u'Bewegte Mann, Der (1994)')
# (812, u'Magic Hunter (1994)')
# (813, u'Larger Than Life (1996)')
# (814, u'Boy Called Hate, A (1995)')
# (815, u'Power 98 (1995)')
# (816, u'Two Deaths (1995)')
# (818, u'Very Brady Sequel, A (1996)')
# (819, u'Stefano Quantestorie (1993)')
# (820, u'Death in the Garden (Mort en ce jardin, La) (1956)')
# (821, u'Crude Oasis, The (1995)')
# (822, u'Hedd Wyn (1992)')
# (823, u'Collectionneuse, La (1967)')
# (824, u'Kaspar Hauser (1993)')
# (825, u'Echte Kerle (1996)')
# (826, u'Diebinnen (1995)')
# (827, u'Convent, The (Convento, O) (1995)')
# (828, u'Adventures of Pinocchio, The (1996)')
# (829, u"Joe's Apartment (1996)")
# (830, u'First Wives Club, The (1996)')
# (831, u'Stonewall (1995)')
# (832, u'Ransom (1996)')
# (833, u'High School High (1996)')
# (834, u'Phat Beach (1996)')
# (835, u'Foxfire (1996)')
# (836, u'Chain Reaction (1996)')
# (837, u'Matilda (1996)')
# (838, u'Emma (1996)')
# (839, u'Crow: City of Angels, The (1996)')
# (840, u'House Arrest (1996)')
# (841, u'Eyes Without a Face (1959)')
# (842, u'Tales from the Crypt Presents: Bordello of Blood (1996)')
# (843, u'Lotto Land (1995)')
# (844, u'Story of Xinghua, The (1993)')
# (845, u'Day the Sun Turned Cold, The (Tianguo niezi) (1994)')
# (846, u'Flirt (1995)')
# (847, u'Big Squeeze, The (1996)')
# (848, u'Spitfire Grill, The (1996)')
# (849, u'Escape from L.A. (1996)')
# (850, u'Cyclo (1995)')
# (851, u'Basquiat (1996)')
# (852, u'Tin Cup (1996)')
# (853, u'Dingo (1992)')
# (854, u'Ballad of Narayama, The (Narayama Bushiko) (1958)')
# (855, u'Every Other Weekend (1990)')
# (856, u'Mille bolle blu (1993)')
# (857, u'Crows and Sparrows (1949)')
# (858, u'Godfather, The (1972)')
# (859, u'Hippie Revolution, The (1996)')
# (860, u'Maybe, Maybe Not (Bewegte Mann, Der) (1994)')
# (861, u'Supercop (1992)')
# (862, u'Manny & Lo (1996)')
# (863, u'Celestial Clockwork (1994)')
# (864, u'Wife, The (1995)')
# (865, u'Small Faces (1995)')
# (866, u'Bound (1996)')
# (867, u'Carpool (1996)')
# (868, u'Death in Brunswick (1991)')
# (869, u'Kansas City (1996)')
# (870, u"Gone Fishin' (1997)")
# (871, u"Lover's Knot (1996)")
# (872, u'Aiqing wansui (1994)')
# (873, u'Shadow of Angels (Schatten der Engel) (1976)')
# (874, u'Killer: A Journal of Murder (1995)')
# (875, u'Nothing to Lose (1994)')
# (876, u'Police Story 4: Project S (Chao ji ji hua) (1993)')
# (877, u'Girls Town (1996)')
# (878, u'Bye-Bye (1995)')
# (879, u'Relic, The (1997)')
# (880, u'Island of Dr. Moreau, The (1996)')
# (881, u'First Kid (1996)')
# (882, u'Trigger Effect, The (1996)')
# (884, u'Sweet Nothing (1995)')
# (885, u'Bogus (1996)')
# (886, u'Bulletproof (1996)')
# (887, u'Talk of Angels (1998)')
# (888, u'Land Before Time III: The Time of the Great Giving (1995)')
# (889, u'1-900 (1994)')
# (890, u'Baton Rouge (1988)')
# (891, u'Halloween: The Curse of Michael Myers (1995)')
# (892, u'Twelfth Night (1996)')
# (893, u'Mother Night (1996)')
# (894, u'Liebelei (1933)')
# (895, u'Venice/Venice (1992)')
# (896, u'Wild Reeds (1994)')
# (897, u'For Whom the Bell Tolls (1943)')
# (898, u'Philadelphia Story, The (1940)')
# (899, u"Singin' in the Rain (1952)")
# (900, u'American in Paris, An (1951)')
# (901, u'Funny Face (1957)')
# (902, u"Breakfast at Tiffany's (1961)")
# (903, u'Vertigo (1958)')
# (904, u'Rear Window (1954)')
# (905, u'It Happened One Night (1934)')
# (906, u'Gaslight (1944)')
# (907, u'Gay Divorcee, The (1934)')
# (908, u'North by Northwest (1959)')
# (909, u'Apartment, The (1960)')
# (910, u'Some Like It Hot (1959)')
# (911, u'Charade (1963)')
# (912, u'Casablanca (1942)')
# (913, u'Maltese Falcon, The (1941)')
# (914, u'My Fair Lady (1964)')
# (915, u'Sabrina (1954)')
# (916, u'Roman Holiday (1953)')
# (917, u'Little Princess, The (1939)')
# (918, u'Meet Me in St. Louis (1944)')
# (919, u'Wizard of Oz, The (1939)')
# (920, u'Gone with the Wind (1939)')
# (921, u'My Favorite Year (1982)')
# (922, u'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)')
# (923, u'Citizen Kane (1941)')
# (924, u'2001: A Space Odyssey (1968)')
# (925, u'Golden Earrings (1947)')
# (926, u'All About Eve (1950)')
# (927, u'Women, The (1939)')
# (928, u'Rebecca (1940)')
# (929, u'Foreign Correspondent (1940)')
# (930, u'Notorious (1946)')
# (931, u'Spellbound (1945)')
# (932, u'Affair to Remember, An (1957)')
# (933, u'To Catch a Thief (1955)')
# (934, u'Father of the Bride (1950)')
# (935, u'Band Wagon, The (1953)')
# (936, u'Ninotchka (1939)')
# (937, u'Love in the Afternoon (1957)')
# (938, u'Gigi (1958)')
# (939, u'Reluctant Debutante, The (1958)')
# (940, u'Adventures of Robin Hood, The (1938)')
# (941, u'Mark of Zorro, The (1940)')
# (942, u'Laura (1944)')
# (943, u'Ghost and Mrs. Muir, The (1947)')
# (944, u'Lost Horizon (1937)')
# (945, u'Top Hat (1935)')
# (946, u'To Be or Not to Be (1942)')
# (947, u'My Man Godfrey (1936)')
# (948, u'Giant (1956)')
# (949, u'East of Eden (1955)')
# (950, u'Thin Man, The (1934)')
# (951, u'His Girl Friday (1940)')
# (952, u'Around the World in 80 Days (1956)')
# (953, u"It's a Wonderful Life (1946)")
# (954, u'Mr. Smith Goes to Washington (1939)')
# (955, u'Bringing Up Baby (1938)')
# (956, u'Penny Serenade (1941)')
# (957, u'Scarlet Letter, The (1926)')
# (958, u'Lady of Burlesque (1943)')
# (959, u'Of Human Bondage (1934)')
# (960, u'Angel on My Shoulder (1946)')
# (961, u'Little Lord Fauntleroy (1936)')
# (962, u'They Made Me a Criminal (1939)')
# (963, u'Inspector General, The (1949)')
# (964, u'Angel and the Badman (1947)')
# (965, u'39 Steps, The (1935)')
# (966, u'Walk in the Sun, A (1945)')
# (967, u'Outlaw, The (1943)')
# (968, u'Night of the Living Dead (1968)')
# (969, u'African Queen, The (1951)')
# (970, u'Beat the Devil (1954)')
# (971, u'Cat on a Hot Tin Roof (1958)')
# (972, u'Last Time I Saw Paris, The (1954)')
# (973, u'Meet John Doe (1941)')
# (974, u'Algiers (1938)')
# (975, u'Something to Sing About (1937)')
# (976, u'Farewell to Arms, A (1932)')
# (977, u'Moonlight Murder (1936)')
# (978, u'Blue Angel, The (Blaue Engel, Der) (1930)')
# (979, u'Nothing Personal (1995)')
# (980, u'In the Line of Duty 2 (1987)')
# (981, u'Dangerous Ground (1997)')
# (982, u'Picnic (1955)')
# (983, u'Madagascar Skin (1995)')
# (984, u'Pompatus of Love, The (1996)')
# (985, u'Small Wonders (1996)')
# (986, u'Fly Away Home (1996)')
# (987, u'Bliss (1997)')
# (988, u'Grace of My Heart (1996)')
# (989, u'Schlafes Bruder (Brother of Sleep) (1995)')
# (990, u'Maximum Risk (1996)')
# (991, u'Michael Collins (1996)')
# (992, u"Rich Man's Wife, The (1996)")
# (993, u'Infinity (1996)')
# (994, u'Big Night (1996)')
# (996, u'Last Man Standing (1996)')
# (997, u'Caught (1996)')
# (998, u'Set It Off (1996)')
# (999, u'2 Days in the Valley (1996)')
# (1000, u'Curdled (1996)')
# (1001, u"Associate, The (L'Associe)(1982)")
# (1002, u"Ed's Next Move (1996)")
# (1003, u'Extreme Measures (1996)')
# (1004, u'Glimmer Man, The (1996)')
# (1005, u'D3: The Mighty Ducks (1996)')
# (1006, u'Chamber, The (1996)')
# (1007, u'Apple Dumpling Gang, The (1975)')
# (1008, u'Davy Crockett, King of the Wild Frontier (1955)')
# (1009, u'Escape to Witch Mountain (1975)')
# (1010, u'Love Bug, The (1969)')
# (1011, u'Herbie Rides Again (1974)')
# (1012, u'Old Yeller (1957)')
# (1013, u'Parent Trap, The (1961)')
# (1014, u'Pollyanna (1960)')
# (1015, u'Homeward Bound: The Incredible Journey (1993)')
# (1016, u'Shaggy Dog, The (1959)')
# (1017, u'Swiss Family Robinson (1960)')
# (1018, u'That Darn Cat! (1965)')
# (1019, u'20,000 Leagues Under the Sea (1954)')
# (1020, u'Cool Runnings (1993)')
# (1021, u'Angels in the Outfield (1994)')
# (1022, u'Cinderella (1950)')
# (1023, u'Winnie the Pooh and the Blustery Day (1968)')
# (1024, u'Three Caballeros, The (1945)')
# (1025, u'Sword in the Stone, The (1963)')
# (1026, u'So Dear to My Heart (1949)')
# (1027, u'Robin Hood: Prince of Thieves (1991)')
# (1028, u'Mary Poppins (1964)')
# (1029, u'Dumbo (1941)')
# (1030, u"Pete's Dragon (1977)")
# (1031, u'Bedknobs and Broomsticks (1971)')
# (1032, u'Alice in Wonderland (1951)')
# (1033, u'Fox and the Hound, The (1981)')
# (1034, u'Freeway (1996)')
# (1035, u'Sound of Music, The (1965)')
# (1036, u'Die Hard (1988)')
# (1037, u'Lawnmower Man, The (1992)')
# (1038, u'Unhook the Stars (1996)')
# (1039, u'Synthetic Pleasures (1995)')
# (1040, u'Secret Agent, The (1996)')
# (1041, u'Secrets & Lies (1996)')
# (1042, u'That Thing You Do! (1996)')
# (1043, u'To Gillian on Her 37th Birthday (1996)')
# (1044, u'Surviving Picasso (1996)')
# (1045, u'Love Is All There Is (1996)')
# (1046, u'Beautiful Thing (1996)')
# (1047, u'Long Kiss Goodnight, The (1996)')
# (1049, u'Ghost and the Darkness, The (1996)')
# (1050, u'Looking for Richard (1996)')
# (1051, u'Trees Lounge (1996)')
# (1052, u'Proprietor, The (1996)')
# (1053, u'Normal Life (1996)')
# (1054, u'Get on the Bus (1996)')
# (1055, u'Shadow Conspiracy (1997)')
# (1056, u'Jude (1996)')
# (1057, u'Everyone Says I Love You (1996)')
# (1058, u'Bitter Sugar (Azucar Amargo) (1996)')
# (1059, u"William Shakespeare's Romeo and Juliet (1996)")
# (1060, u'Swingers (1996)')
# (1061, u'Sleepers (1996)')
# (1062, u'Sunchaser, The (1996)')
# (1063, u'Johns (1996)')
# (1064, u'Aladdin and the King of Thieves (1996)')
# (1065, u'Woman in Question, The (1950)')
# (1066, u'Shall We Dance? (1937)')
# (1067, u'Damsel in Distress, A (1937)')
# (1068, u'Crossfire (1947)')
# (1069, u'Murder, My Sweet (1944)')
# (1070, u'Macao (1952)')
# (1071, u'For the Moment (1994)')
# (1073, u'Willy Wonka and the Chocolate Factory (1971)')
# (1075, u'Sexual Life of the Belgians, The (1994)')
# (1076, u'Innocents, The (1961)')
# (1077, u'Sleeper (1973)')
# (1078, u'Bananas (1971)')
# (1079, u'Fish Called Wanda, A (1988)')
# (1080, u"Monty Python's Life of Brian (1979)")
# (1081, u'Victor/Victoria (1982)')
# (1082, u'Candidate, The (1972)')
# (1083, u'Great Race, The (1965)')
# (1084, u'Bonnie and Clyde (1967)')
# (1085, u'Old Man and the Sea, The (1958)')
# (1086, u'Dial M for Murder (1954)')
# (1087, u'Madame Butterfly (1995)')
# (1088, u'Dirty Dancing (1987)')
# (1089, u'Reservoir Dogs (1992)')
# (1090, u'Platoon (1986)')
# (1091, u"Weekend at Bernie's (1989)")
# (1092, u'Basic Instinct (1992)')
# (1093, u'Doors, The (1991)')
# (1094, u'Crying Game, The (1992)')
# (1095, u'Glengarry Glen Ross (1992)')
# (1096, u"Sophie's Choice (1982)")
# (1097, u'E.T. the Extra-Terrestrial (1982)')
# (1098, u'Search for One-eye Jimmy, The (1996)')
# (1099, u'Christmas Carol, A (1938)')
# (1100, u'Days of Thunder (1990)')
# (1101, u'Top Gun (1986)')
# (1102, u'American Strays (1996)')
# (1103, u'Rebel Without a Cause (1955)')
# (1104, u'Streetcar Named Desire, A (1951)')
# (1105, u'Children of the Corn IV: The Gathering (1996)')
# (1106, u'Leopard Son, The (1996)')
# (1107, u'Loser (1991)')
# (1108, u'Prerokbe Ognja (1995)')
# (1109, u"Charm's Incidents (1996)")
# (1110, u'Bird of Prey (1996)')
# (1111, u"Microcosmos (Microcosmos: Le peuple de l'herbe) (1996)")
# (1112, u'Palookaville (1996)')
# (1113, u'Associate, The (1996)')
# (1114, u'Funeral, The (1996)')
# (1115, u'Sleepover (1995)')
# (1116, u'Single Girl, A (La Fille Seule) (1995)')
# (1117, u'Eighth Day, The (Le Huiti\ufffdme jour ) (1996)')
# (1118, u'Tashunga (1995)')
# (1119, u'Drunks (1997)')
# (1120, u'People vs. Larry Flynt, The (1996)')
# (1121, u'Glory Daze (1996)')
# (1122, u'Plutonium Circus (1995)')
# (1123, u'Perfect Candidate, A (1996)')
# (1124, u'On Golden Pond (1981)')
# (1125, u'Return of the Pink Panther, The (1974)')
# (1126, u'Drop Dead Fred (1991)')
# (1127, u'Abyss, The (1989)')
# (1128, u'Fog, The (1980)')
# (1129, u'Escape from New York (1981)')
# (1130, u'Howling, The (1980)')
# (1131, u'Jean de Florette (1986)')
# (1132, u'Manon of the Spring (Manon des sources) (1986)')
# (1133, u'Talking About Sex (1994)')
# (1134, u'Johnny 100 Pesos (1993)')
# (1135, u'Private Benjamin (1980)')
# (1136, u'Monty Python and the Holy Grail (1974)')
# (1137, u'Hustler White (1996)')
# (1138, u'Dadetown (1995)')
# (1139, u'Everything Relative (1996)')
# (1140, u'Entertaining Angels: The Dorothy Day Story (1996)')
# (1141, u'Hoogste tijd (1995)')
# (1142, u'Get Over It (1996)')
# (1143, u'Three Lives and Only One Death (1996)')
# (1144, u'Line King: Al Hirschfeld, The (1996)')
# (1145, u'Snowriders (1996)')
# (1146, u"Curtis's Charm (1995)")
# (1147, u'When We Were Kings (1996)')
# (1148, u'Wrong Trousers, The (1993)')
# (1149, u'JLG/JLG - autoportrait de d\ufffdcembre (1994)')
# (1150, u'Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982)')
# (1151, u'Faust (1994)')
# (1152, u'He Walked by Night (1948)')
# (1153, u'Raw Deal (1948)')
# (1154, u'T-Men (1947)')
# (1155, u'Invitation, The (Zaproszenie) (1986)')
# (1156, u'Children Are Watching us, The (Bambini ci guardano, I) (1942)')
# (1157, u'Symphonie pastorale, La (1946)')
# (1158, u'Here Comes Cookie (1935)')
# (1159, u'Love in Bloom (1935)')
# (1160, u'Six of a Kind (1934)')
# (1161, u'Tin Drum, The (Blechtrommel, Die) (1979)')
# (1162, u'Ruling Class, The (1972)')
# (1163, u'Mina Tannenbaum (1994)')
# (1164, u'Two or Three Things I Know About Her (1966)')
# (1165, u'Bloody Child, The (1996)')
# (1166, u'Farmer & Chase (1995)')
# (1167, u'Dear God (1996)')
# (1168, u'Bad Moon (1996)')
# (1169, u'American Dream (1990)')
# (1170, u'Best of the Best 3: No Turning Back (1995)')
# (1171, u'Bob Roberts (1992)')
# (1172, u'Cinema Paradiso (1988)')
# (1173, u'Cook the Thief His Wife & Her Lover, The (1989)')
# (1174, u'Grosse Fatigue (1994)')
# (1175, u'Delicatessen (1991)')
# (1176, u'Double Life of Veronique, The (La Double Vie de V\ufffdronique) (1991)')
# (1177, u'Enchanted April (1991)')
# (1178, u'Paths of Glory (1957)')
# (1179, u'Grifters, The (1990)')
# (1180, u'Hear My Song (1991)')
# (1181, u'Shooter, The (1995)')
# (1183, u'English Patient, The (1996)')
# (1184, u'Mediterraneo (1991)')
# (1185, u'My Left Foot (1989)')
# (1186, u'Sex, Lies, and Videotape (1989)')
# (1187, u'Passion Fish (1992)')
# (1188, u'Strictly Ballroom (1992)')
# (1189, u'Thin Blue Line, The (1988)')
# (1190, u'Tie Me Up! Tie Me Down! (1990)')
# (1191, u'Madonna: Truth or Dare (1991)')
# (1192, u'Paris Is Burning (1990)')
# (1193, u"One Flew Over the Cuckoo's Nest (1975)")
# (1194, u'Up in Smoke (1978)')
# (1196, u'Star Wars: Episode V - The Empire Strikes Back (1980)')
# (1197, u'Princess Bride, The (1987)')
# (1198, u'Raiders of the Lost Ark (1981)')
# (1199, u'Brazil (1985)')
# (1200, u'Aliens (1986)')
# (1201, u'Good, The Bad and The Ugly, The (1966)')
# (1202, u'Withnail and I (1987)')
# (1203, u'12 Angry Men (1957)')
# (1204, u'Lawrence of Arabia (1962)')
# (1205, u'Transformers: The Movie, The (1986)')
# (1206, u'Clockwork Orange, A (1971)')
# (1207, u'To Kill a Mockingbird (1962)')
# (1208, u'Apocalypse Now (1979)')
# (1209, u'Once Upon a Time in the West (1969)')
# (1210, u'Star Wars: Episode VI - Return of the Jedi (1983)')
# (1211, u'Wings of Desire (Der Himmel \ufffdber Berlin) (1987)')
# (1212, u'Third Man, The (1949)')
# (1213, u'GoodFellas (1990)')
# (1214, u'Alien (1979)')
# (1215, u'Army of Darkness (1993)')
# (1216, u'Big Blue, The (Le Grand Bleu) (1988)')
# (1217, u'Ran (1985)')
# (1218, u'Killer, The (Die xue shuang xiong) (1989)')
# (1219, u'Psycho (1960)')
# (1220, u'Blues Brothers, The (1980)')
# (1221, u'Godfather: Part II, The (1974)')
# (1222, u'Full Metal Jacket (1987)')
# (1223, u'Grand Day Out, A (1992)')
# (1224, u'Henry V (1989)')
# (1225, u'Amadeus (1984)')
# (1226, u'Quiet Man, The (1952)')
# (1227, u'Once Upon a Time in America (1984)')
# (1228, u'Raging Bull (1980)')
# (1230, u'Annie Hall (1977)')
# (1231, u'Right Stuff, The (1983)')
# (1232, u'Stalker (1979)')
# (1233, u'Boat, The (Das Boot) (1981)')
# (1234, u'Sting, The (1973)')
# (1235, u'Harold and Maude (1971)')
# (1236, u'Trust (1990)')
# (1237, u'Seventh Seal, The (Sjunde inseglet, Det) (1957)')
# (1238, u'Local Hero (1983)')
# (1240, u'Terminator, The (1984)')
# (1241, u'Braindead (1992)')
# (1242, u'Glory (1989)')
# (1243, u'Rosencrantz and Guildenstern Are Dead (1990)')
# (1244, u'Manhattan (1979)')
# (1245, u"Miller's Crossing (1990)")
# (1246, u'Dead Poets Society (1989)')
# (1247, u'Graduate, The (1967)')
# (1248, u'Touch of Evil (1958)')
# (1249, u'Nikita (La Femme Nikita) (1990)')
# (1250, u'Bridge on the River Kwai, The (1957)')
# (1251, u'8 1/2 (1963)')
# (1252, u'Chinatown (1974)')
# (1253, u'Day the Earth Stood Still, The (1951)')
# (1254, u'Treasure of the Sierra Madre, The (1948)')
# (1255, u'Bad Taste (1987)')
# (1256, u'Duck Soup (1933)')
# (1257, u'Better Off Dead... (1985)')
# (1258, u'Shining, The (1980)')
# (1259, u'Stand by Me (1986)')
# (1260, u'M (1931)')
# (1261, u'Evil Dead II (Dead By Dawn) (1987)')
# (1262, u'Great Escape, The (1963)')
# (1263, u'Deer Hunter, The (1978)')
# (1264, u'Diva (1981)')
# (1265, u'Groundhog Day (1993)')
# (1266, u'Unforgiven (1992)')
# (1267, u'Manchurian Candidate, The (1962)')
# (1268, u'Pump Up the Volume (1990)')
# (1269, u'Arsenic and Old Lace (1944)')
# (1270, u'Back to the Future (1985)')
# (1271, u'Fried Green Tomatoes (1991)')
# (1272, u'Patton (1970)')
# (1273, u'Down by Law (1986)')
# (1274, u'Akira (1988)')
# (1275, u'Highlander (1986)')
# (1276, u'Cool Hand Luke (1967)')
# (1277, u'Cyrano de Bergerac (1990)')
# (1278, u'Young Frankenstein (1974)')
# (1279, u'Night on Earth (1991)')
# (1280, u'Raise the Red Lantern (1991)')
# (1281, u'Great Dictator, The (1940)')
# (1282, u'Fantasia (1940)')
# (1283, u'High Noon (1952)')
# (1284, u'Big Sleep, The (1946)')
# (1285, u'Heathers (1989)')
# (1286, u'Somewhere in Time (1980)')
# (1287, u'Ben-Hur (1959)')
# (1288, u'This Is Spinal Tap (1984)')
# (1289, u'Koyaanisqatsi (1983)')
# (1290, u'Some Kind of Wonderful (1987)')
# (1291, u'Indiana Jones and the Last Crusade (1989)')
# (1292, u'Being There (1979)')
# (1293, u'Gandhi (1982)')
# (1294, u'M*A*S*H (1970)')
# (1295, u'Unbearable Lightness of Being, The (1988)')
# (1296, u'Room with a View, A (1986)')
# (1297, u'Real Genius (1985)')
# (1298, u'Pink Floyd - The Wall (1982)')
# (1299, u'Killing Fields, The (1984)')
# (1300, u'My Life as a Dog (Mitt liv som hund) (1985)')
# ...
# (3522, u'Sacco and Vanzetti (Sacco e Vanzetti) (1971)')
# (3523, u'Taffin (1988)')
# (3524, u'Arthur (1981)')
# (3525, u'Bachelor Party (1984)')
# (3526, u'Parenthood (1989)')
# (3527, u'Predator (1987)')
# (3528, u'Prince of Tides, The (1991)')
# (3529, u'Postman Always Rings Twice, The (1981)')
# (3530, u'Smoking/No Smoking (1993)')
# (3531, u'All the Vermeers in New York (1990)')
# (3532, u'Freedom for Us (\ufffd nous la libert\ufffd ) (1931)')
# (3533, u"Actor's Revenge, An (Yukinojo Henge) (1963)")
# (3534, u'28 Days (2000)')
# (3535, u'American Psycho (2000)')
# (3536, u'Keeping the Faith (2000)')
# (3537, u'Where the Money Is (2000)')
# (3538, u'East is East (1999)')
# (3539, u'Filth and the Fury, The (2000)')
# (3540, u'Passion of Mind (1999)')
# (3541, u'Third World Cop (1999)')
# (3542, u'Coming Apart (1969)')
# (3543, u'Diner (1982)')
# (3544, u'Shakes the Clown (1991)')
# (3545, u'Cabaret (1972)')
# (3546, u'What Ever Happened to Baby Jane? (1962)')
# (3547, u'Prick Up Your Ears (1987)')
# (3548, u'Auntie Mame (1958)')
# (3549, u'Guys and Dolls (1955)')
# (3550, u'Hunger, The (1983)')
# (3551, u'Marathon Man (1976)')
# (3552, u'Caddyshack (1980)')
# (3553, u'Gossip (2000)')
# (3554, u'Love and Basketball (2000)')
# (3555, u'U-571 (2000)')
# (3556, u'Virgin Suicides, The (1999)')
# (3557, u'Jennifer 8 (1992)')
# (3558, u'Law, The (Le Legge) (1958)')
# (3559, u'Limelight (1952)')
# (3560, u'Phantom Love (Ai No Borei) (1978)')
# (3561, u"Stacy's Knights (1982)")
# (3562, u'Committed (2000)')
# (3563, u'Crow: Salvation, The (2000)')
# (3564, u'Flintstones in Viva Rock Vegas, The (2000)')
# (3565, u'Where the Heart Is (2000)')
# (3566, u'Big Kahuna, The (2000)')
# (3567, u'Bossa Nova (1999)')
# (3568, u'Smiling Fish and Goat on Fire (1999)')
# (3569, u'Idiots, The (Idioterne) (1998)')
# (3570, u'Last September, The (1999)')
# (3571, u'Time Code (2000)')
# (3572, u'Carnosaur (1993)')
# (3573, u'Carnosaur 2 (1995)')
# (3574, u'Carnosaur 3: Primal Species (1996)')
# (3575, u'Defying Gravity (1997)')
# (3576, u'Hidden, The (1987)')
# (3577, u'Two Moon Juction (1988)')
# (3578, u'Gladiator (2000)')
# (3579, u'I Dreamed of Africa (2000)')
# (3580, u'Up at the Villa (2000)')
# (3581, u'Human Traffic (1999)')
# (3582, u'Jails, Hospitals & Hip-Hop (2000)')
# (3583, u'Black Tights (Les Collants Noirs) (1960)')
# (3584, u'Breathless (1983)')
# (3585, u'Great Locomotive Chase, The (1956)')
# (3586, u'Idolmaker, The (1980)')
# (3587, u'Inferno (1980)')
# (3588, u'King of Marvin Gardens, The (1972)')
# (3589, u'Kill, Baby... Kill! (Operazione Paura) (1966)')
# (3590, u'Lords of Flatbush, The (1974)')
# (3591, u'Mr. Mom (1983)')
# (3592, u'Time Masters (Les Ma\ufffdtres du Temps) (1982)')
# (3593, u'Battlefield Earth (2000)')
# (3594, u'Center Stage (2000)')
# (3595, u'Held Up (2000)')
# (3596, u'Screwed (2000)')
# (3597, u'Whipped (2000)')
# (3598, u'Hamlet (2000)')
# (3599, u'Anchors Aweigh (1945)')
# (3600, u'Blue Hawaii (1961)')
# (3601, u'Castaway Cowboy, The (1974)')
# (3602, u'G. I. Blues (1960)')
# (3603, u'Gay Deceivers, The (1969)')
# (3604, u'Gypsy (1962)')
# (3605, u'King Creole (1958)')
# (3606, u'On the Town (1949)')
# (3607, u'One Little Indian (1973)')
# (3608, u"Pee-wee's Big Adventure (1985)")
# (3609, u'Regret to Inform (1998)')
# (3610, u'Roustabout (1964)')
# (3611, u'Saludos Amigos (1943)')
# (3612, u'Slipper and the Rose, The (1976)')
# (3613, u'Things Change (1988)')
# (3614, u'Honeymoon in Vegas (1992)')
# (3615, u'Dinosaur (2000)')
# (3616, u'Loser (2000)')
# (3617, u'Road Trip (2000)')
# (3618, u'Small Time Crooks (2000)')
# (3619, u'Hollywood Knights, The (1980)')
# (3620, u'Myth of Fingerprints, The (1997)')
# (3621, u'Possession (1981)')
# (3622, u'Twelve Chairs, The (1970)')
# (3623, u'Mission: Impossible 2 (2000)')
# (3624, u'Shanghai Noon (2000)')
# (3625, u'Better Living Through Circuitry (1999)')
# (3626, u'8 1/2 Women (1999)')
# (3627, u'Carnival of Souls (1962)')
# (3628, u'Flying Tigers (1942)')
# (3629, u'Gold Rush, The (1925)')
# (3630, u"House of Exorcism, The (La Casa dell'esorcismo) (1974)")
# (3631, u"It's in the Water (1998)")
# (3632, u'Monsieur Verdoux (1947)')
# (3633, u"On Her Majesty's Secret Service (1969)")
# (3634, u'Seven Days in May (1964)')
# (3635, u'Spy Who Loved Me, The (1977)')
# (3636, u"Those Who Love Me Can Take the Train (Ceux qui m'aiment prendront le train) (1998)")
# (3637, u'Vagabond (Sans toit ni loi) (1985)')
# (3638, u'Moonraker (1979)')
# (3639, u'Man with the Golden Gun, The (1974)')
# (3640, u'King in New York, A (1957)')
# (3641, u'Woman of Paris, A (1923)')
# (3642, u'In Old California (1942)')
# (3643, u'Fighting Seabees, The (1944)')
# (3644, u'Dark Command (1940)')
# (3645, u'Cleo From 5 to 7 (Cl\ufffdo de 5 \ufffd 7) (1962)')
# (3646, u"Big Momma's House (2000)")
# (3647, u'Running Free (2000)')
# (3648, u'Abominable Snowman, The (1957)')
# (3649, u'American Gigolo (1980)')
# (3650, u'Anguish (Angustia) (1986)')
# (3651, u'Blood Spattered Bride, The (La Novia Ensangrentada) (1972)')
# (3652, u'City of the Living Dead (Paura nella citt\ufffd dei morti viventi) (1980)')
# (3653, u'Endless Summer, The (1966)')
# (3654, u'Guns of Navarone, The (1961)')
# (3655, u'Blow-Out (La Grande Bouffe) (1973)')
# (3656, u'Lured (1947)')
# (3657, u'Pandora and the Flying Dutchman (1951)')
# (3658, u'Quatermass and the Pit (1967)')
# (3659, u'Quatermass II (1957)')
# (3660, u'Puppet Master (1989)')
# (3661, u'Puppet Master II (1990)')
# (3662, u"Puppet Master III: Toulon's Revenge (1991)")
# (3663, u'Puppet Master 4 (1993)')
# (3664, u'Puppet Master 5: The Final Chapter (1994)')
# (3665, u'Curse of the Puppet Master (1998)')
# (3666, u'Retro Puppetmaster (1999)')
# (3667, u'Rent-A-Cop (1988)')
# (3668, u'Romeo and Juliet (1968)')
# (3669, u'Stay Tuned (1992)')
# (3670, u'Story of G.I. Joe, The (1945)')
# (3671, u'Blazing Saddles (1974)')
# (3672, u'Benji (1974)')
# (3673, u'Benji the Hunted (1987)')
# (3674, u'For the Love of Benji (1977)')
# (3675, u'White Christmas (1954)')
# (3676, u'Eraserhead (1977)')
# (3677, u'Baraka (1992)')
# (3678, u'Man with the Golden Arm, The (1955)')
# (3679, u'Decline of Western Civilization, The (1981)')
# (3680, u'Decline of Western Civilization Part II: The Metal Years, The (1988)')
# (3681, u'For a Few Dollars More (1965)')
# (3682, u'Magnum Force (1973)')
# (3683, u'Blood Simple (1984)')
# (3684, u'Fabulous Baker Boys, The (1989)')
# (3685, u"Prizzi's Honor (1985)")
# (3686, u'Flatliners (1990)')
# (3687, u'Light Years (1988)')
# (3688, u"Porky's (1981)")
# (3689, u"Porky's II: The Next Day (1983)")
# (3690, u"Porky's Revenge (1985)")
# (3691, u'Private School (1983)')
# (3692, u"Class of Nuke 'Em High (1986)")
# (3693, u'Toxic Avenger, The (1985)')
# (3694, u'Toxic Avenger, Part II, The (1989)')
# (3695, u'Toxic Avenger Part III: The Last Temptation of Toxie, The (1989)')
# (3696, u'Night of the Creeps (1986)')
# (3697, u'Predator 2 (1990)')
# (3698, u'Running Man, The (1987)')
# (3699, u'Starman (1984)')
# (3700, u'Brother from Another Planet, The (1984)')
# (3701, u'Alien Nation (1988)')
# (3702, u'Mad Max (1979)')
# (3703, u'Mad Max 2 (a.k.a. The Road Warrior) (1981)')
# (3704, u'Mad Max Beyond Thunderdome (1985)')
# (3705, u'Bird on a Wire (1990)')
# (3706, u'Angel Heart (1987)')
# (3707, u'Nine 1/2 Weeks (1986)')
# (3708, u'Firestarter (1984)')
# (3709, u'Sleepwalkers (1992)')
# (3710, u'Action Jackson (1988)')
# (3711, u'Sarafina! (1992)')
# (3712, u'Soapdish (1991)')
# (3713, u'Long Walk Home, The (1990)')
# (3714, u"Clara's Heart (1988)")
# (3715, u'Burglar (1987)')
# (3716, u'Fatal Beauty (1987)')
# (3717, u'Gone in 60 Seconds (2000)')
# (3718, u'American Pimp (1999)')
# (3719, u"Love's Labour's Lost (2000)")
# (3720, u'Sunshine (1999)')
# (3721, u'Trixie (1999)')
# (3722, u'Live Virgin (1999)')
# (3723, u'Hamlet (1990)')
# (3724, u'Coming Home (1978)')
# (3725, u'American Pop (1981)')
# (3726, u'Assault on Precinct 13 (1976)')
# (3727, u'Near Dark (1987)')
# (3728, u'One False Move (1991)')
# (3729, u'Shaft (1971)')
# (3730, u'Conversation, The (1974)')
# (3731, u"Cutter's Way (1981)")
# (3732, u'Fury, The (1978)')
# (3733, u'Paper Chase, The (1973)')
# (3734, u'Prince of the City (1981)')
# (3735, u'Serpico (1973)')
# (3736, u'Big Carnival, The (1951)')
# (3737, u'Lonely Are the Brave (1962)')
# (3738, u'Sugarland Express, The (1974)')
# (3739, u'Trouble in Paradise (1932)')
# (3740, u'Big Trouble in Little China (1986)')
# (3741, u'Badlands (1973)')
# (3742, u'Battleship Potemkin, The (Bronenosets Potyomkin) (1925)')
# (3743, u'Boys and Girls (2000)')
# (3744, u'Shaft (2000)')
# (3745, u'Titan A.E. (2000)')
# (3746, u'Butterfly (La Lengua de las Mariposas) (2000)')
# (3747, u"Jesus' Son (1999)")
# (3748, u'Match, The (1999)')
# (3749, u'Time Regained (Le Temps Retrouv\ufffd) (1999)')
# (3750, u"Boricua's Bond (2000)")
# (3751, u'Chicken Run (2000)')
# (3752, u'Me, Myself and Irene (2000)')
# (3753, u'Patriot, The (2000)')
# (3754, u'Adventures of Rocky and Bullwinkle, The (2000)')
# (3755, u'Perfect Storm, The (2000)')
# (3756, u'Golden Bowl, The (2000)')
# (3757, u'Asylum (1972)')
# (3758, u'Communion (1989)')
# (3759, u'Fun and Fancy Free (1947)')
# (3760, u'Kentucky Fried Movie, The (1977)')
# (3761, u'Blood In, Blood Out (a.k.a. Bound by Honor) (1993)')
# (3762, u'Daughter of Dr. Jeckyll (1957)')
# (3763, u'F/X (1986)')
# (3764, u'F/X 2 (1992)')
# (3765, u'Hot Spot, The (1990)')
# (3766, u'Missing in Action (1984)')
# (3767, u'Missing in Action 2: The Beginning (1985)')
# (3768, u'Braddock: Missing in Action III (1988)')
# (3769, u'Thunderbolt and Lightfoot (1974)')
# (3770, u'Dreamscape (1984)')
# (3771, u'Golden Voyage of Sinbad, The (1974)')
# (3772, u'Hatchet For the Honeymoon (Rosso Segno Della Follia) (1969)')
# (3773, u'House Party (1990)')
# (3774, u'House Party 2 (1991)')
# (3775, u'Make Mine Music (1946)')
# (3776, u'Melody Time (1948)')
# (3777, u'Nekromantik (1987)')
# (3778, u'On Our Merry Way (1948)')
# (3779, u'Project Moon Base (1953)')
# (3780, u'Rocketship X-M (1950)')
# (3781, u'Shaft in Africa (1973)')
# (3782, u"Shaft's Big Score! (1972)")
# (3783, u'Croupier (1998)')
# (3784, u'Kid, The (2000)')
# (3785, u'Scary Movie (2000)')
# (3786, u"But I'm a Cheerleader (1999)")
# (3787, u'Shower (Xizhao) (1999)')
# (3788, u'Blowup (1966)')
# (3789, u'Pawnbroker, The (1965)')
# (3790, u'Groove (2000)')
# (3791, u'Footloose (1984)')
# (3792, u'Duel in the Sun (1946)')
# (3793, u'X-Men (2000)')
# (3794, u'Chuck & Buck (2000)')
# (3795, u'Five Senses, The (1999)')
# (3796, u'Wisdom of Crocodiles, The (a.k.a. Immortality) (2000)')
# (3797, u'In Crowd, The (2000)')
# (3798, u'What Lies Beneath (2000)')
# (3799, u'Pok\ufffdmon the Movie 2000 (2000)')
# (3800, u'Criminal Lovers (Les Amants Criminels) (1999)')
# (3801, u'Anatomy of a Murder (1959)')
# (3802, u'Freejack (1992)')
# (3803, u"Greaser's Palace (1972)")
# (3804, u'H.O.T.S. (1979)')
# (3805, u'Knightriders (1981)')
# (3806, u"MacKenna's Gold (1969)")
# (3807, u'Sinbad and the Eye of the Tiger (1977)')
# (3808, u'Two Women (La Ciociara) (1961)')
# (3809, u'What About Bob? (1991)')
# (3810, u'White Sands (1992)')
# (3811, u'Breaker Morant (1980)')
# (3812, u'Everything You Always Wanted to Know About Sex (1972)')
# (3813, u'Interiors (1978)')
# (3814, u'Love and Death (1975)')
# (3816, u'Official Story, The (La Historia Oficial) (1985)')
# (3817, u'Other Side of Sunday, The (S\ufffdndagsengler) (1996)')
# (3818, u"Pot O' Gold (1941)")
# (3819, u'Tampopo (1986)')
# (3820, u'Thomas and the Magic Railroad (2000)')
# (3821, u'Nutty Professor II: The Klumps (2000)')
# (3822, u'Girl on the Bridge, The (La Fille sur le Pont) (1999)')
# (3823, u'Wonderland (1999)')
# (3824, u'Autumn in New York (2000)')
# (3825, u'Coyote Ugly (2000)')
# (3826, u'Hollow Man (2000)')
# (3827, u'Space Cowboys (2000)')
# (3828, u'Better Living (1998)')
# (3829, u'Mad About Mambo (2000)')
# (3830, u'Psycho Beach Party (2000)')
# (3831, u'Saving Grace (2000)')
# (3832, u'Black Sabbath (Tre Volti Della Paura, I) (1963)')
# (3833, u"Brain That Wouldn't Die, The (1962)")
# (3834, u'Bronco Billy (1980)')
# (3835, u'Crush, The (1993)')
# (3836, u"Kelly's Heroes (1970)")
# (3837, u'Phantasm II (1988)')
# (3838, u'Phantasm III: Lord of the Dead (1994)')
# (3839, u'Phantasm IV: Oblivion (1998)')
# (3840, u'Pumpkinhead (1988)')
# (3841, u'Air America (1990)')
# (3842, u'Make Them Die Slowly (Cannibal Ferox) (1980)')
# (3843, u'Sleepaway Camp (1983)')
# (3844, u'Steel Magnolias (1989)')
# (3845, u'And God Created Woman (Et Dieu&#8230;Cr\ufffda la Femme) (1956)')
# (3846, u'Easy Money (1983)')
# (3847, u'Ilsa, She Wolf of the SS (1974)')
# (3848, u'Silent Fall (1994)')
# (3849, u'Spiral Staircase, The (1946)')
# (3850, u'Whatever Happened to Aunt Alice? (1969)')
# (3851, u"I'm the One That I Want (2000)")
# (3852, u'Tao of Steve, The (2000)')
# (3853, u'Tic Code, The (1998)')
# (3854, u'Aim\ufffde & Jaguar (1999)')
# (3855, u'Affair of Love, An (Une Liaison Pornographique) (1999)')
# (3856, u'Autumn Heart (1999)')
# (3857, u'Bless the Child (2000)')
# (3858, u'Cecil B. Demented (2000)')
# (3859, u'Eyes of Tammy Faye, The (2000)')
# (3860, u'Opportunists, The (1999)')
# (3861, u'Replacements, The (2000)')
# (3862, u'About Adam (2000)')
# (3863, u'Cell, The (2000)')
# (3864, u'Godzilla 2000 (Gojira ni-sen mireniamu) (1999)')
# (3865, u'Original Kings of Comedy, The (2000)')
# (3866, u'Sunset Strip (2000)')
# (3867, u"All the Rage (a.k.a. It's the Rage) (1999)")
# (3868, u'Naked Gun: From the Files of Police Squad!, The (1988)')
# (3869, u'Naked Gun 2 1/2: The Smell of Fear, The (1991)')
# (3870, u'Our Town (1940)')
# (3871, u'Shane (1953)')
# (3872, u'Suddenly, Last Summer (1959)')
# (3873, u'Cat Ballou (1965)')
# (3874, u'Couch in New York, A (1996)')
# (3875, u'Devil Rides Out, The (1968)')
# (3876, u'Jerry & Tom (1998)')
# (3877, u'Supergirl (1984)')
# (3878, u'X: The Unknown (1956)')
# (3879, u'Art of War, The (2000)')
# (3880, u"Ballad of Ramblin' Jack, The (2000)")
# (3881, u'Bittersweet Motel (2000)')
# (3882, u'Bring It On (2000)')
# (3883, u'Catfish in Black Bean Sauce (2000)')
# (3884, u'Crew, The (2000)')
# (3885, u'Love & Sex (2000)')
# (3886, u'Steal This Movie! (2000)')
# (3887, u'Went to Coney Island on a Mission From God... Be Back by Five (1998)')
# (3888, u'Skipped Parts (2000)')
# (3889, u'Highlander: Endgame (2000)')
# (3890, u'Back Stage (2000)')
# (3891, u'Turn It Up (2000)')
# (3892, u'Anatomy (Anatomie) (2000)')
# (3893, u'Nurse Betty (2000)')
# (3894, u'Solas (1999)')
# (3895, u'Watcher, The (2000)')
# (3896, u'Way of the Gun, The (2000)')
# (3897, u'Almost Famous (2000)')
# (3898, u'Bait (2000)')
# (3899, u'Circus (2000)')
# (3900, u'Crime and Punishment in Suburbia (2000)')
# (3901, u'Duets (2000)')
# (3902, u'Goya in Bordeaux (Goya en Bodeos) (1999)')
# (3903, u'Urbania (2000)')
# (3904, u'Uninvited Guest, An (2000)')
# (3905, u'Specials, The (2000)')
# (3906, u'Under Suspicion (2000)')
# (3907, u'Prince of Central Park, The (1999)')
# (3908, u'Urban Legends: Final Cut (2000)')
# (3909, u'Woman on Top (2000)')
# (3910, u'Dancer in the Dark (2000)')
# (3911, u'Best in Show (2000)')
# (3912, u'Beautiful (2000)')
# (3913, u'Barenaked in America (1999)')
# (3914, u'Broken Hearts Club, The (2000)')
# (3915, u'Girlfight (2000)')
# (3916, u'Remember the Titans (2000)')
# (3917, u'Hellraiser (1987)')
# (3918, u'Hellbound: Hellraiser II (1988)')
# (3919, u'Hellraiser III: Hell on Earth (1992)')
# (3920, u'Faraway, So Close (In Weiter Ferne, So Nah!) (1993)')
# (3921, u'Beach Party (1963)')
# (3922, u'Bikini Beach (1964)')
# (3923, u'Return of the Fly (1959)')
# (3924, u'Pajama Party (1964)')
# (3925, u'Stranger Than Paradise (1984)')
# (3926, u'Voyage to the Bottom of the Sea (1961)')
# (3927, u'Fantastic Voyage (1966)')
# (3928, u'Abbott and Costello Meet Frankenstein (1948)')
# (3929, u'Bank Dick, The (1940)')
# (3930, u'Creature From the Black Lagoon, The (1954)')
# (3931, u'Giant Gila Monster, The (1959)')
# (3932, u'Invisible Man, The (1933)')
# (3933, u'Killer Shrews, The (1959)')
# (3934, u'Kronos (1957)')
# (3935, u'Kronos (1973)')
# (3936, u'Phantom of the Opera, The (1943)')
# (3937, u'Runaway (1984)')
# (3938, u'Slumber Party Massacre, The (1982)')
# (3939, u'Slumber Party Massacre II, The (1987)')
# (3940, u'Slumber Party Massacre III, The (1990)')
# (3941, u'Sorority House Massacre (1986)')
# (3942, u'Sorority House Massacre II (1990)')
# (3943, u'Bamboozled (2000)')
# (3944, u'Bootmen (2000)')
# (3945, u'Digimon: The Movie (2000)')
# (3946, u'Get Carter (2000)')
# (3947, u'Get Carter (1971)')
# (3948, u'Meet the Parents (2000)')
# (3949, u'Requiem for a Dream (2000)')
# (3950, u'Tigerland (2000)')
# (3951, u'Two Family House (2000)')
# (3952, u'Contender, The (2000)')

# %% [markdown]
# #### The user ID 0 is unassigned, so we will use it for your ratings. We set the variable `myUserID` to 0 for you. Next, create a new RDD `myRatingsRDD` with your ratings for at least 10 movie ratings. Each entry should be formatted as `(myUserID, movieID, rating)` (i.e., each entry should be formatted in the same way as `trainingRDD`).  As in the original dataset, ratings should be between 1 and 5 (inclusive). If you have not seen at least 10 of these movies, you can increase the parameter passed to `take()` in the above cell until there are 10 movies that you have seen (or you can also guess what your rating would be for movies you have not seen).

# %%
# TODO: Replace <FILL IN> with appropriate code
myUserID = 0

# Note that the movie IDs are the *last* number on each line. A common error was to use the number of ratings as the movie ID.
myRatedMovies = [
     (0,328,5.0),
     (0,858,4.9),
     (0,1221,4.9),
     (0,2762,4.8),
     (0,2826,4.9),
     (0,593,4.7),
     (0,2324,5.0),
     (0,296,4.8),
     (0,1704,4.95),
     (0,2028,4.9),
     (0,1193,5.0)
     # The format of each line is (myUserID, movie ID, your rating)
     # For example, to give the movie "Star Wars: Episode IV - A New Hope (1977)" a five rating, you would add the following line:
     #   (myUserID, 260, 5),
    ]
myRatingsRDD = sc.parallelize(myRatedMovies)
print 'My movie ratings: %s' % myRatingsRDD.take(10)
# Out:
# My movie ratings: [(0, 328, 5.0), (0, 858, 4.9), (0, 1221, 4.9), (0, 2762, 4.8), (0, 2826, 4.9), (0, 593, 4.7), (0, 2324, 5.0), (0, 296, 4.8), (0, 1704, 4.95), (0, 2028, 4.9)]

# %% [markdown]
# #### **(3b) Add Your Movies to Training Dataset**
# #### Now that you have ratings for yourself, you need to add your ratings to the `training` dataset so that the model you train will incorporate your preferences.  Spark's [union()](http://spark.apache.org/docs/latest/api/python/pyspark.rdd.RDD-class.html#union) transformation combines two RDDs; use `union()` to create a new training dataset that includes your ratings and the data in the original training dataset.

# %%
# TODO: Replace <FILL IN> with appropriate code
trainingWithMyRatingsRDD = trainingRDD.union(myRatingsRDD)

print ('The training dataset now has %s more entries than the original training dataset' %
       (trainingWithMyRatingsRDD.count() - trainingRDD.count()))
assert (trainingWithMyRatingsRDD.count() - trainingRDD.count()) == myRatingsRDD.count()
# Out:
# The training dataset now has 11 more entries than the original training dataset

# %% [markdown]
# #### **(3c) Train a Model with Your Ratings**
# #### Now, train a model with your ratings added and the parameters you used in in part (2c): `bestRank`, `seed=seed`, `iterations=iterations`, and `lambda_=regularizationParameter` - make sure you include **all** of the parameters.

# %%
# TODO: Replace <FILL IN> with appropriate code
myRatingsModel = ALS.train(trainingWithMyRatingsRDD, bestRank, seed=seed, iterations=iterations, lambda_=regularizationParameter)

# %% [markdown]
# #### **(3d) Check RMSE for the New Model with Your Ratings**
# #### Compute the RMSE for this new model on the test set.
# * #### For the prediction step, we reuse `testForPredictingRDD`, consisting of (UserID, MovieID) pairs that you extracted from `testRDD`. The RDD has the form: `[(1, 1287), (1, 594), (1, 1270)]`
# * #### Use `myRatingsModel.predictAll()` to predict rating values for the `testForPredictingRDD` test dataset, set this as `predictedTestMyRatingsRDD`
# * #### For validation, use the `testRDD`and your `computeError` function to compute the RMSE between `testRDD` and the `predictedTestMyRatingsRDD` from the model.

# %%
# TODO: Replace <FILL IN> with appropriate code
predictedTestMyRatingsRDD = myRatingsModel.predictAll(testForPredictingRDD)
testRMSEMyRatings = computeError(testRDD, predictedTestMyRatingsRDD)
print 'The model had a RMSE on the test set of %s' % testRMSEMyRatings
# Out:
# The model had a RMSE on the test set of 0.891965513602

# %% [markdown]
# #### **(3e) Predict Your Ratings**
# #### So far, we have only used the `predictAll` method to compute the error of the model.  Here, use the `predictAll` to predict what ratings you would give to the movies that you did not already provide ratings for.
# #### The steps you should perform are:
# * #### Use the Python list `myRatedMovies` to transform the `moviesRDD` into an RDD with entries that are pairs of the form (myUserID, Movie ID) and that does not contain any movies that you have rated. This transformation will yield an RDD of the form: `[(0, 1), (0, 2), (0, 3), (0, 4)]`. Note that you can do this step with one RDD transformation.
# * #### For the prediction step, use the input RDD, `myUnratedMoviesRDD`, with myRatingsModel.predictAll() to predict your ratings for the movies.

# %%
# TODO: Replace <FILL IN> with appropriate code

# Use the Python list myRatedMovies to transform the moviesRDD into an RDD with entries that are pairs of the form (myUserID, Movie ID) and that does not contain any movies that you have rated.
myUnratedMoviesRDD = (moviesRDD
                      .map(lambda (MovieID, Title): (myUserID, MovieID))
                      .filter(lambda (myUserID, MovieID): (myUserID, MovieID) not in [(user, movie) for (user,movie,rating) in myRatedMovies]))

# Use the input RDD, myUnratedMoviesRDD, with myRatingsModel.predictAll() to predict your ratings for the movies
predictedRatingsRDD = myRatingsModel.predictAll(myUnratedMoviesRDD)

# %% [markdown]
# #### **(3f) Predict Your Ratings**
# #### We have our predicted ratings. Now we can print out the 25 movies with the highest predicted ratings.
# #### The steps you should perform are:
# * #### From Parts (1b) and (1c), we know that we should look at movies with a reasonable number of reviews (e.g., more than 75 reviews). You can experiment with a lower threshold, but fewer ratings for a movie may yield higher prediction errors. Transform `movieIDsWithAvgRatingsRDD` from Part (1b), which has the form (MovieID, (number of ratings, average rating)), into an RDD of the form (MovieID, number of ratings): `[(2, 332), (4, 71), (6, 442)]`
# * #### We want to see movie names, instead of movie IDs. Transform `predictedRatingsRDD` into an RDD with entries that are pairs of the form (Movie ID, Predicted Rating): `[(3456, -0.5501005376936687), (1080, 1.5885892024487962), (320, -3.7952255522487865)]`
# * #### Use RDD transformations with `predictedRDD` and `movieCountsRDD` to yield an RDD with tuples of the form (Movie ID, (Predicted Rating, number of ratings)): `[(2050, (0.6694097486155939, 44)), (10, (5.29762541533513, 418)), (2060, (0.5055259373841172, 97))]`
# * #### Use RDD transformations with `predictedWithCountsRDD` and `moviesRDD` to yield an RDD with tuples of the form (Predicted Rating, Movie Name, number of ratings), _for movies with more than 75 ratings._ For example: `[(7.983121900375243, u'Under Siege (1992)'), (7.9769201864261285, u'Fifth Element, The (1997)')]`

# %%
# TODO: Replace <FILL IN> with appropriate code

# Transform movieIDsWithAvgRatingsRDD from part (1b), which has the form (MovieID, (number of ratings, average rating)), into and RDD of the form (MovieID, number of ratings)
movieCountsRDD = movieIDsWithAvgRatingsRDD.map(lambda (MovieID, (numRatings, avgRating)): (MovieID, numRatings))

# Transform predictedRatingsRDD into an RDD with entries that are pairs of the form (Movie ID, Predicted Rating)
predictedRDD = predictedRatingsRDD.map(lambda (UserID, MovieID, Rating): (MovieID, Rating))

# Use RDD transformations with predictedRDD and movieCountsRDD to yield an RDD with tuples of the form (Movie ID, (Predicted Rating, number of ratings))
predictedWithCountsRDD  = (predictedRDD
                           .join(movieCountsRDD)) 

# Use RDD transformations with PredictedWithCountsRDD and moviesRDD to yield an RDD with tuples of the form (Predicted Rating, Movie Name, number of ratings), for movies with more than 75 ratings
ratingsWithNamesRDD = (predictedWithCountsRDD
                       .join(moviesRDD)
                       .map(lambda (MovieID, ((rating, numRatings), MovieName)): (rating, MovieName, numRatings))
                       .filter(lambda (rating, MovieName, numRatings): numRatings > 75))

predictedHighestRatedMovies = ratingsWithNamesRDD.takeOrdered(20, key=lambda x: -x[0])
print ('My highest rated movies as predicted (for movies with more than 75 reviews):\n%s' %
        '\n'.join(map(str, predictedHighestRatedMovies)))
# Out:
# My highest rated movies as predicted (for movies with more than 75 reviews):
# (5.263840214351083, u'Paths of Glory (1957)', 105)
# (5.207675740267096, u'Matrix, The (1999)', 1250)
# (5.151684004888397, u'Star Wars: Episode IV - A New Hope (1977)', 1447)
# (5.148649453282918, u'Star Wars: Episode V - The Empire Strikes Back (1980)', 1438)
# (5.1238416316219855, u'Raiders of the Lost Ark (1981)', 1195)
# (5.105597575320846, u'Killer, The (Die xue shuang xiong) (1989)', 117)
# (5.095130372087692, u'Braveheart (1995)', 1300)
# (5.095106369470612, u'Monty Python and the Holy Grail (1974)', 759)
# (5.083414465566295, u'Princess Mononoke, The (Mononoke Hime) (1997)', 210)
# (5.072584013606506, u'Shawshank Redemption, The (1994)', 1088)
# (5.029905352609831, u'Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)', 278)
# (5.027751471586175, u'Gladiator (2000)', 1013)
# (5.010750993619828, u'Usual Suspects, The (1995)', 831)
# (5.0000233859641385, u'Close Shave, A (1995)', 318)
# (4.9936928100239815, u'American History X (1998)', 341)
# (4.952988526811428, u'Wrong Trousers, The (1993)', 425)
# (4.950437844451834, u'Central Station (Central do Brasil) (1998)', 103)
# (4.939453360844223, u'Terminator, The (1984)', 983)
# (4.911521481108796, u'Hard-Boiled (Lashou shentan) (1992)', 154)
# (4.908348476048898, u'Great Escape, The (1963)', 360)
